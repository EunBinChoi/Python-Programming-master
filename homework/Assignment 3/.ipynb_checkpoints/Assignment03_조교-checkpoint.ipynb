# %% [markdown]
# ## Assignment 3

# %% [markdown]
# ---
# <b>한국기술교육대학교 컴퓨터공학부<br>
# 스크립트 프로그래밍(Script Programming)<br>
# 2014136129 최은빈
# ___

# %% [markdown]
# ### 1번 문제

# %% [markdown]
# - L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.

# %% [markdown]
# - 1)
#        L[1:3] = [100]
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# > 1) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신 100이 들어가게 되어 [1, 100, 4, 5]와 같은 형태로 리스트가 변경됩니다.

# %% [markdown]
# - 2)
#        L[1:3] = [(100)]
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# > 2) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신 (100)이 들어갔습니다. 이는 괄호로 감싸져 있지만 원소가 하나이고, 콤마를 사용하지 않았으므로 튜플이 아닙니다. 즉, 그냥 숫자이므로 위의 1) 과 같은 결과로 출력됩니다.

# %% [markdown]
# - 3)
#        L[1:3] = 100
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = 100
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-edc1b0549df9> in <module>()
#       1 L = [1, 2, 3, 4, 5]
# ----> 2 L[1:3] = 100
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# > 3) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신 그냥 숫자 100을 주었습니다. 오류 메세지를 살펴보면 숫자 100은 iterable 이 아니라서 에러가 발생한다는 것을 알 수 있습니다. iterable은 member를 하나씩 반환할 수 있는 객체를 말하는데, 예로는  리스트, 문자열, 튜플 등이 있습니다. 이러한 자료형은 반복이 가능하며 L[1:3]을 대체하여 들어갈 수 있지만, 숫자 100의 경우, 반복이 불가능하기 때문에 오류가 발생합니다.

# %% [markdown]
# - 4)
#        L[1:3] = (100)
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-fcb29dd6421c> in <module>()
#       1 L = [1, 2, 3, 4, 5]
# ----> 2 L[1:3] = (100)
#       3 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# > 4) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신 (100)을 주었습니다. 이 경우, 괄호로 감싸져있긴 하지만 원소가 하나인데도 불구하고 콤마가 없으므로, 이 역시도 그냥 숫자 100으로 인식합니다. 즉, 3) 의 경우와 똑같은 이유로 오류가 발생했다고 볼 수 있습니다.

# %% [markdown]
# - 5)
#        L[1:3] = (100, 101, 102)
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = (100, 101, 102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# > 5) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신에 100,101,102가 들어가게 됩니다. 튜플은 반복이 가능한 자료형이므로 오류가 발생하지 않고 잘 출력됩니다.

# %% [markdown]
# - 6)
#        L[1:3] = [100, 101, 102]
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [100, 101, 102]
print (L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# > 6) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신에 100,101.102가 들어가게 됩니다. 리스트는 반복이 가능한 자료형이므로 오류가 발생하지 않고 잘 출력됩니다.

# %% [markdown]
# - 7)
#        L[1:3] = [(100, 101, 102)]
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [(100, 101, 102)]
print (L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# > 7) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신에 튜플 (100,101,102)가 들어가게 됩니다. 튜플은 원소 하나로 취급되어 위치 1,2에 해당하는 자리에 잘 들어간 것을 확인할 수 있습니다.

# %% [markdown]
# - 8)
#        L[1:3] = [[100, 101, 102]]
#        print(L)

# %%
L = [1, 2, 3, 4, 5]
L[1:3] = [[100, 101, 102]]
print (L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# > 8) 의 경우, 위치 1부터 2에 해당하는 원소 2와 3 대신에 리스트 [100,101,102]가 들어가게 됩니다. 리스트는 원소 하나로 취급되어 위치 1,2에 해당하는 자리에 잘 들어간 것을 확인할 수 있습니다.

# %% [markdown]
# ### 2번 문제

# %% [markdown]
# - 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
#     - 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#     - 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
s = 'Hello World and Python'
wordlist = s.split() # 반환형 리스트
wordlist.reverse()
ans1 = ' '.join(wordlist)
print (ans1) 

wordlist = ans1.split()
ans2 = ''.join(wordlist)
print (ans2)
# Out:
# Python and World Hello
# PythonandWorldHello

# %% [markdown]
# > - 먼저 1)를 해결하기 위해 주어진 문자열 S를 단어 단위로 분리해 리스트에 넣어주고 그것의 순서를 reverse() 함수로 역순으로 바꾸어줍니다. 그리고 그 단어들의 사이가 ' ' 으로 이어진 문자열을 만들어 출력해주었습니다.<br><br>
# > - 다음으로 2)를 해결하기 위해 문제 1)의 결과인 ans1를 다시 단어로 분리한 다음, 그것을 ''(아무 값이 쓰이지 않은 것)으로 이어진 문자열을 만들어 출력해주었습니다. ''으로 이어주게 되면 단어들끼리 공백없이 다 이어지게 됩니다.

# %% [markdown]
# ### 3번 문제

# %% [markdown]
# - 다음 코드를 보고 물음에 답하시오.
#       a = [1, 2, 3]
#       b = a * 3
#       c = [a] * 3
#       print(b)
#       print(c)
#      - 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#             a[0]=0
#      - 2) b와 c 객체의 차이는 무엇인가?

# %%
a = [1, 2, 3]
b = a * 3
c = [a] * 3
print (b)
print (c)

print ()
a[0] = 0 # 문제 1번
print (b)
print (c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
#
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# > - 1) 의 경우, b의 내용은 [1, 2, 3, 1, 2, 3, 1, 2, 3]이 되었고, c의 내용은 [[1, 2, 3], [1, 2, 3], [1, 2, 3]]이 되었습니다.<br><br>
#
# > - 2) 에서 b 객체는 a 리스트를 3번 반복하여 새롭게 만들어진 리스트입니다. 반면에 c 객체는 a 리스트를 3번 참조하여 만들어졌습니다. 즉, c 객체는 리스트 안에 a가 3번 담긴 형태입니다. 따라서 a를 변경하면, b는 아무런 변화가 없는 반면에 c는 [a, a, a]와 같은 형태이므로 a의 변화가 반영됩니다.

# %% [markdown]
# ### 4번 문제

# %% [markdown]
# - 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#       s = '  first star   :   second star   :    third star  '
#       l = ['first star', 'second star', 'third star']
#     - 1) for ~ in 문을 이용한 코드를 작성하시오.
#     - 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '
l = ['first star', 'second star', 'third star']

tmp = s.split(':') # : 을 기준으로 분리하기

# 문제 1. for~in문
ans1 = []
for word in tmp:
    ans1.append(word.strip())
print (ans1)

# 문제 2. 리스트 내포
ans2 = [word.strip() for word in tmp]
print (ans2)
# Out:
# ['first star', 'second star', 'third star']
# ['first star', 'second star', 'third star']

# %% [markdown]
# > - 먼저 문자열을 : 를 기준으로 나누기 위해 split 메소드를 이용했습니다.
# > - 1) 의 경우, tmp에 저장된 단어들을 하나씩 불러와 좌우공백을 없애기 위하여 strip해서 리스트 ans1에 하나씩 append 메소드를 이용하여 넣어줍니다.
# > - 2) 의 경우, tmp에 저장된 단어들을 strip 해줘서 그대로 리스트 ans2의 원소로  삼을 수 있도록 만들어줍니다.

# %% [markdown]
# ### 5번 문제

# %% [markdown]
# - 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
#     - 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#                 >>> addall([1])
#                 1
#
#                 >>> addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
#                 45
#     - 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
#                 >>> addallodd([1])
#                 1
#                 >>> addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9])
#                 25
#     - [참고 1]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)
#     - [참고 2]: sum() 등의 내장함수 사용 가능함

# %%
# 1번 for ~ in 구문
def addall(li):
    sum = 0;
    for i in range(len(li)):
        sum += li[i]
    return sum
print (addall([1]))
print (addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 1
# 45

# %%
# 1번 리스트 내포
def addall(li):
    return sum([i for i in li])
print (addall([1]))
print (addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 1
# 45

# %% [markdown]
# > - 5번 문제의 1) 의 경우, for~in을 사용할 때는 먼저 정수의 합을 담고 있을 변수 sum을 0으로 초기화해주고, for~in 구문을 리스트의 원소 갯수만큼 돌면서 리스트의 원소들을 sum에 더해주었습니다. 마지막으로 원소들의 합을 담고 있는 sum 변수를 반환하는 것으로 addall 함수를 작성하였습니다. <br><br>
# > - 반면에 리스트 내포 방식을 사용할 때에는 리스트 내의 원소들의 합을 구하기 위해 sum이라는 내장함수를 이용하였습니다. 리스트를 인자로 받아온 후, 리스트 내의 숫자들로 리스트를 생성하여 그 리스트를 sum이라는 내장함수의 인자로 줍니다. 그리고 그 결과를 반환하는 것으로 addall 함수를 작성하였습니다.

# %%
# 2번 for ~ in 구문
def addallodd(li):
    sum = 0
    for i in range (len(li)):
        if(li[i] % 2 == 1):
            sum += li[i]
    return sum
print (addallodd([1]))
print (addallodd([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 25

# %%
# 2번 리스트 내포
def addallodd(li):
    return sum([i for i in li if(i % 2 == 1)])
print (addallodd([1]))
print (addallodd([1,2,3,4,5,6,7,8,9]))
# Out:
# 1
# 25

# %% [markdown]
# > - 5번 문제의 2) 의 경우, for~in을 사용할 때에는 먼저 홀수의 합을 담고 있을 변수 sum을 0으로 초기화해주고, for~in 구문을 리스트의 원소 갯수만큼 돌면서, 만약 리스트의 원소가 2로 나눈 나머지가 1(홀수가 되기 위한 조건)라면, sum에 해당 리스트의 원소를 더해줍니다. 그리고 마지막으로 홀수의 합을 담고 있는 sum 변수를 반환하는 것으로 addallodd 함수를 작성하였습니다. <br><br>
# > - 반면에 리스트 내포 방식을 사용할 때에는 리스트 내의 홀수의 합을 구하기 위해 sum이라는 내장함수를 아용하였습니다. 리스트를 인자로 받아온 후, 리스트 내의 숫자들로 리스트를 생성하는데, 이 과정에서 해당 리스트 원소를 2로 나눈 나머지가 1(홀수가 되기 위한 조건)인 경우에만 리스트의 원소로 들어갈 수 있도록 하였고, 이렇게 만들어진 리스트를 sum이라는 내장함수의 인자로 주고, 그 결과를 반환하는 것으로 함수를 작성하였습니다.

# %% [markdown]
# ### 6번 문제

# %% [markdown]
# - 다음 코드를 보고 물음에 답하시오.
#           L1 = [1, 2, 3]
#           L2 = [4, 5, 6]
#           d = {'low':L1, 'high':L2}
#           e = d
#           f = d.copy()
#           print(d)
#           print(e)
#           print(f)
#           print()
#           d['low'] = [10, 20, 30]
#           d['high'][1] = 500
#           print(d)
#           print(e)
#           print(f)
#     - 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
#     - 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
#             {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print(d)
print(e)
print(f)
print()
d['low'] = [10, 20, 30]
d['high'][1] = 500
print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
#
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# > - 1) 의 경우, e에는 d가 가리키는 객체의 주소가 담겨지게 되는데, 즉 e에는 d에 담긴 사전의 레퍼런스가 들어가게 됩니다. 따라서 d가 가리키는 객체와 e가 가리키는 객체는 같아지기 때문에 d와 e는 항상 같은 결과를 출력합니다.<br><br>
# > - 2) 의 경우, f = d.copy()와 같은 코드에서 얕은 복사(shallow copy)가 일어났기 때문에 발생한 결과입니다. copy를 이용하여 복사를 진행할 경우, 깊은 복사가 아닌 얕은 복사가 일어납니다. 그 경우, 리스트 안에 존재하는 (각 객체를 가리키는)원소는 공유되게 되어 별도의 객체가 존재하지 않습니다. 따라서 d['high'][1] = 500와 같은 코드가 주어졌을 때, 공유하고 있는 객체의 변화로 인해 f에서도 바뀐 값이 출력되게 되었습니다. 반면에 d['low'] = [10, 20, 30]와 같은 코드가 주어졌을 때, 사전 d의 key인 'low'는 [10, 20, 30]와 같은 새로운 리스트 객체를 가리키게 되고, 얇은 복사에 의해 f는 기존의 리스트 객체를 가리키게 되므로(f는 새로운 객체를 가리키지 않음, f는 기존의 리스트 객체를 가리킴(얇은 복사의 원리)) [1,2,3]이 출력됩니다.

# %% [markdown]
# ### 7번 문제

# %% [markdown]
# - 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#     - [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#     - 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     - 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     - 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#     - 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
def newKey(item):  # 추가로 구현된 코드에서 사용된 함수
    return item[1]

d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}

# 1) 번 문제
tmp = list(d.keys())
tmp.sort()
for key in tmp:
    print ((key, d[key]), end = " ")
    
print()

# 2) 번 문제
tmp = list(d.keys())
tmp.sort(reverse = True)
for key in tmp:
    print ((key, d[key]), end = " ")
    
print()



# 3) 번 문제
tmp = list(d.values())
tmp.sort()
for value in tmp:
    for key in d.keys():
        if(d[key] == value):
            print ((key, d[key]), end = " ")
            
print()


# 4) 번 문제
tmp = list(d.values())
tmp.sort(reverse = True)
for value in tmp:
    for key in d.keys():
        if(d[key] == value):
            print ((key, d[key]), end = " ")
# Out:
# ('five', 5) ('four', 4) ('one', 1) ('three', 3) ('two', 2)
# ('two', 2) ('three', 3) ('one', 1) ('four', 4) ('five', 5)
# ('one', 1) ('two', 2) ('three', 3) ('four', 4) ('five', 5)
# ('five', 5) ('four', 4) ('three', 3) ('two', 2) ('one', 1)

# %% [markdown]
# > - 1) 의 경우, 키의 알파벳 오름차순 순서대로 튜플을 출력하는 것이므로, 먼저 d.keys()으로 사전의 키를 얻은 후, 이를 리스트로 변경해줍니다. 그리고 sort 함수를 통해 오름차순으로 정렬한 뒤, 반복문을 통해 오름차순으로 정렬된 각 키와 그 키에 해당하는 값을 튜플 형식으로 출력해주었습니다.<br><br>
# > - 2) 의 경우, 키의 알파벳 내림차순 순서대로 튜플을 출력하는 것이므로, 먼저 d.keys()으로 사전의 키를 얻은 후, 이를 리스트로 변경해줍니다. 그리고 sort 함수의 인자 reverse를 True 값으로 주어 내림차순으로 정렬한 뒤, 반복문을 통해 내림차순으로 정렬된 각 키와 그 키에 해당하는 값을 튜플 형식으로 출력해주었습니다.<br><br>
# > - 3) 의 경우, 값의 오른차순 순서대로 튜플 (키, 값)을 차례대로 출력하는 것이므로, d.values()으로 각 키에 대한 값을 얻은 후, 이를 리스트로 변경해줍니다. 그리고 sort 함수를 통해 각 키에 대한 값을 오름차순으로 정렬한 뒤, 반복문을 통해 오름차순으로 정렬된 값과 각 키에 해당하는 값을 비교하여 같을 경우 (키, 값)을 출력해주었습니다. <br><br>
# > - 4) 의 경우, 값의 오른차순 순서대로 튜플 (키, 값)을 차례대로 출력하는 것이므로, d.values()으로 각 키에 대한 값을 얻은 후, 이를 리스트로 변경해줍니다. 그리고 sort 함수의 인자 reverse를 True 값으로 주어 각 키에 대한 값을 내림차순으로 정렬한 뒤, 반복문을 통해 내림차순으로 정렬된 값과 각 키에 해당하는 값을 비교하여 같을 경우 (키, 값)을 출력해주었습니다.

# %% [markdown]
# ### 8번 문제

# %% [markdown]
# - [ACM-ICPC 문제 1152번]
#     - 단어의 개수<br>
#      https://www.acmicpc.net/problem/1152
#      - 영어 대소문자와 띄어쓰기만으로 이루어진 문장이 주어진다. 이 문장에는 몇 개의 단어가 있을까? 이를 구하는 프로그램을 작성하시오. 단, 단어는 띄어쓰기 하나로 구분된다고 생각한다.
#
#         - [입력] 첫 줄에 영어 대소문자와 띄어쓰기로 이루어진 문장이 주어진다. 이 문장의 길이는 1,000,000을 넘지 않는다.
#         - [출력] 첫째 줄에 단어의 개수를 출력한다.

# %%
def countVoca(item):
    sp = item.split()
    cnt = len(sp)
    return cnt

sentence = input()
print(countVoca(sentence))
# Out:
# The Curious Case of Benjamin Button
# 6

# %% [markdown]
# > - 먼저 문장의 단어 개수를 반환해주는 countVoca 함수를 정의합니다. countVoca 함수에서는 split 함수를 이용하여 공백(띄어쓰기)를 기준으로 문장을 잘라줍니다. 이렇게 하게 되면 문장 내에 존재하는 단어들이 리스트 형태로 반환되고, 만들어진 리스트의 원소 개수를 len 함수를 이용하여 구해주면 해당 문장의 단어의 개수가 몇 개인지 알게 됩니다. <br><br>
# > - countVoca 함수 외부에서는 사용자에게 영어 대소문자와 띄어쓰기만으로 이루어진 문장을 입력받기 위해 input 함수를 통하여 입력받고. 입력받은 문장을 countVoca 함수의 인자로 주어지게 되면, 결과적으로 사용자가 입력한 문장의 단어 개수를 구할 수 있게 됩니다.

# %% [markdown]
# ![단어의 개수](https://github.com/EunBinChoi/Script-Programming/blob/master/homework/img/1152.png?raw=true)

# %% [markdown]
# ### 9번 문제

# %% [markdown]
# - [Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.
#     - 요구사항 1. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#         - 예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
#         - 모든 punctuation을 확인하는 방법은 아래와 같다.
#                   import string
#                   print(string.punctuation)
#     - 요구사항 2. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#         - 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '지향']
#    - 요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#        - 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2, 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#     - 요구사항 4. 다음 3개의 사이트에 대한 결과를 출력하시오.
#         - http://www.naver.com
#         - http://www.daum.net
#         - http://www.nytimes.com

# %%
from urllib import request 
import string

def IncrementalProject(url):
    f = request.urlopen(url)
    source_bytes = f.read()
    source = source_bytes.decode('utf-8')
    text = ''

    # 주석 제거
    while ('<!--' in source):
        # 주석은 <!-- 과 --> 의 쌍으로 나타내어지므로 index 함수를 사용해 주석을 찾아 없앤다
        left = source.index('<!--')
        right = source.index('-->')
        source = source[:left] + source[right+3:]
    #print(source)
    
    # html &nbsp; &quot; &lt; &gt; &amp; 제거
    while ('&nbsp;' in source):
        left = source.index('&nbsp;')
        right = source.index('&nbsp;')
        source = source[:left] + source[right+6:]    
     
    while ('&quot;' in source):
        left = source.index('&quot;')
        right = source.index('&quot;')
        source = source[:left] + source[right+6:]         
    
    while ('&lt;' in source):
        left = source.index('&lt;')
        right = source.index('&lt;')
        source = source[:left] + source[right+4:]  
      
    while ('&gt;' in source):
        left = source.index('&gt;')
        right = source.index('&gt;')
        source = source[:left] + source[right+4:]  

    while ('&amp;' in source):
        left = source.index('&amp;')
        right = source.index('&amp;')
        source = source[:left] + source[right+5:]  
    
    
    # <script> 태그가 없어질때까지 반복 (javascript 태그)
    while ('<script' in source):
        # <script> 태그 뒤에는 문장이 올 수 있으므로 <script 으로 검사해준다 
        # <script> ~ </script> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
        left = source.index('<script')
        right = source.index('</script>')
        source = source[:left] + source[right+9:]
    
    # <style> 태그가 없어질때까지 반복 (css 태그)
    while ('<style' in source):
        # <style> 태그 뒤에는 문장이 올 수 있으므로 <style 으로 검사해준다 
        # <style> ~ </style> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
        left = source.index('<style')
        right = source.index('</style>')
        source = source[:left] + source[right+8:] 
 
    
    # 태그는 < 과 > 의 쌍으로 나타내어지므로 index 함수를 사용해 태그 부분을 찾아 없앤다.
    while('<' in source):
        left = source.index('<')
        right = source.index('>')
        text = text+' '+source[:left]
        source = source[right+1:]
      

    wordList = {} # { 단어(키) : 단어의 출현 빈도(벨류) } 형식의 사전 정의
    puncList = list(string.punctuation)
    puncList.extend(['’','‘','···','【','】','…','·','»','¢','£','¥','€','®','ⓒ','©']) # 구두문자와 html entity 추가

    for t in text.split(): # 현재 text에 들어 있는 문장은 순수 텍스트이므로 공백을 기준으로 자름
        for char in puncList: 
            t = t.replace(char, '')
        
        if (len(t) > 0):
            if (not t in wordList.keys()):
                wordList[t] = 1
            else:
                wordList[t] = wordList[t] + 1
    
    print(wordList)

# %%
IncrementalProject('http://www.naver.com')
# Out:
# {'NAVER': 3, '뉴스스탠드': 2, '바로가기': 7, '주제별캐스트': 1, '타임스퀘어': 2, '쇼핑캐스트': 2, '로그인': 4, '네이버': 7, '네이버를': 1, '시작페이지로': 1, '쥬니어네이버': 1, '해피빈': 1, '검색': 2, '통합검색': 1, '블로그': 2, '카페': 2, '카페명': 1, '카페글': 1, '지식iN': 1, '뉴스': 3, '사이트': 2, '카테고리': 1, '영화': 4, '웹문서': 1, '사전': 2, '백과사전': 1, '영어사전': 1, '영영사전': 1, '국어사전': 1, '일본어사전': 1, '한자사전': 1, '용어사전': 1, '책': 2, '음악': 1, '전문자료': 1, '쇼핑': 2, '지역': 2, '동영상': 1, '이미지': 1, '내PC': 1, '자동차': 2, '게임': 2, '건강': 3, '인물': 3, '긍정부정검색': 1, '자동완성': 18, '펼치기': 5, '한글': 1, '입력기': 1, '생각한대로': 1, '검색해': 1, '보세요': 3, 'Beta': 1, 'txt': 4, '시간대와': 1, '관심사에': 2, '맞춘': 1, '컨텍스트': 3, '도움말': 6, '보기': 21, 'ON': 1, '선택됨': 1, 'OFF': 1, '동일한': 1, '시간대연령남녀별': 1, '사용자': 1, '그룹의': 1, '맞춰': 1, '자동완성을': 1, '제공합니다': 1, '자세히': 2, 'ONOFF설정은': 1, '해당': 1, '기기브라우저에': 1, '저장됩니다': 1, '레이어': 1, '닫기': 3, '신고': 4, '검색어저장': 6, '켜기': 5, '끄기': 7, '기능을': 5, '다시': 5, '켤': 4, '때는': 4, '을': 4, '클릭하세요': 4, '현재': 1, '사용하고': 1, '계십니다': 1, '기능이': 5, '활성화되었습니다': 1, '꺼져': 3, '있습니다': 5, '최근검색어': 2, '내': 8, '검색어': 7, '등록': 3, 'date': 1, '삭제': 4, 'intxt': 1, '내역이': 1, '없습니다': 3, '저장': 2, '해제': 1, '설정된': 1, '검색어가': 1, '최근검색어에서': 1, '를': 1, '선택하여': 1, '자주': 1, '찾는': 2, '검색어를': 2, '검색어로': 1, '저장해': 1, '알림': 1, '공용': 1, 'PC에서는': 1, '개인정보': 1, '보호를': 1, '위하여': 1, '반드시': 1, '로그아웃을': 1, '해': 1, '주세요': 1, '기록': 3, '전체': 5, '완료': 1, '검색어는': 1, '최대': 1, '10': 3, '개': 1, '까지': 1, '저장할': 1, '수': 2, '추가하시려면': 1, '기존': 1, '지워주세요': 1, '제19대': 1, '대통령선거': 1, '후보에': 1, '대해': 1, '5월': 1, '9일': 1, '선거일까지': 1, '제공되지': 1, '않습니다': 1, '자세히보기': 1, '메일': 1, '지식인': 1, '네이버페이': 1, '네이버TV': 1, '증권금융': 1, '부동산': 1, '지도': 1, '뮤직': 2, '만화': 1, '웹툰': 2, '더보기': 1, '실시간': 2, '급상승': 3, '1': 2, '양지원': 2, '2': 2, '핫샷': 2, '3': 2, '스피카': 2, '4': 2, '더유닛': 2, '5': 2, '태민': 2, '6': 2, '돈꽃': 2, '7': 2, '일대종사': 2, '8': 2, '믹스나인': 2, '9': 2, '그것이': 2, '알고싶다': 2, '
, '세번의': 1, '터치39로': 1, '토트넘': 1, '격침': 1, '승리의': 1, '주역': 1, '팻딘의': 1, '짠물': 1, '피칭': 1, '길고긴': 1, 'VAR': 1, '판독': 1, '끝에': 1, '찾은': 1, '데얀의': 1, '골': 1, '39꽃미소39': 1, '전소민': 1, '시구폼은': 1, '제대로죠': 1, '추울까': 1, '봐': 1, '따뜻한': 1, '난로': 1, '틀어줬더니': 1, '부여잡을': 1, '준비': 1, '하세요': 1, '보는': 1, '사람': 1, '광대': 1, '폭발하는': 1, '앞에서': 1, '안': 2, '달리는': 1, '거': 1, '누구': 1, '차야': 1, '4' ...

# %%
IncrementalProject('http://www.nytimes.com')
# Out:
# {'The': 52, 'New': 21, 'York': 10, 'Times': 12, 'Breaking': 1, 'News': 6, 'World': 5, 'Multimedia': 2, 'NYTimescom': 2, 'no': 1, 'longer': 1, 'supports': 1, 'Internet': 3, 'Explorer': 1, '9': 1, 'or': 3, 'earlier': 1, 'Please': 1, 'upgrade': 1, 'your': 3, 'browser': 1, 'LEARN': 1, 'MORE': 1, 'Sections': 4, 'Search': 5, 'Skip': 2, 'to': 67, 'content': 1, 'navigation': 1, 'Subscribe': 5, 'Now': 7, 'Log': 1, 'In': 8, '0': 1, 'Settings': 1, 'English': 1, '中文': 1, 'Chinese': 1, 'Español': 1, 'Saturday': 1, 'October': 1, '28': 1, '2017': 4, 'Todays': 4, 'Paper': 2, 'Video': 5, 'Quick': 1, 'Site': 11, 'Navigation': 7, 'US': 5, 'Politics': 3, 'NY': 3, 'Business': 5, 'Opinion': 11, 'Tech': 3, 'Science': 4, 'Health': 6, 'Sports': 4, 'Arts': 6, 'Style': 5, 'Food': 7, 'Travel': 5, 'Magazine': 7, 'T': 4, 'Real': 5, 'Estate': 4, 'all': 2, 'Close': 1, 'search': 1, 'Clear': 1, 'this': 3, 'text': 1, 'input': 1, 'Go': 5, 'Mobile': 3, 'Top': 2, 'Conservative': 1, 'Was': 1, 'First': 4, 'Hire': 1, 'Steele': 2, 'Dossier': 2, 'Firm': 1, 'By': 22, 'KENNETH': 1, 'P': 1, 'VOGEL': 1, 'and': 48, 'MAGGIE': 1, 'HABERMAN': 1, 'Washington': 2, 'Free': 1, 'Beacon': 1, 'financed': 1, 'by': 12, 'a': 45, 'major': 2, 'GOP': 2, 'donor': 1, 'retained': 1, 'Fusion': 1, 'GPS': 1, 'find': 1, 'information': 1, 'intended': 1, 'sink': 1, 'Donald': 2, 'J': 1, 'Trumps': 3, 'campaign': 2, 'Later': 1, 'Hillary': 1, 'Clintons': 1, 'also': 1, 'hired': 1, 'the': 62, 'firm': 1, 'which': 2, 'employed': 1, 'former': 1, 'British': 1, 'spy': 1, 'Christopher': 1, 'unearth': 1, 'dirt': 1, 'on': 14, 'Mr': 1, 'Trump': 12, 'that': 10, 'would': 1, 'become': 1, 'infamous': 1, 'dossier': 1, 'Comments': 6, 'What': 6, 'We': 3, 'Know': 1, 'About': 2, 'Kremlin': 2, 'Is': 10, 'Tied': 1, 'Memo': 2, 'in': 41, '16': 1, 'Tower': 2, 'Meeting': 1, 'SHARON': 1, 'LaFRANIERE': 1, 'ANDREW': 1, 'E': 1, 'KRAMER': 1, 'Russian': 1, 'lawyer': 1, 'at': 9, 'June': 1, '2016': 1, 'meeting': 1, 'has': 6, 'denied': 1, 'acting': 1, 'behalf': 1, 'of': 53, 'but': 8, 'records': 1, 'suggest': 1, 'coordination': 1, 'Urged': 2, 'Gag': 2, 'Order': 2, 'Be': 5, 'Lifted': 2, 'Informant': 2, 'Governor': 2, 'Blocked': 2, 'Medicaid': 2, 'Expansion': 2, 'Its': 5, 'Ballot': 1, 'ABBY': 1, 'GOODNOUGH': 1, 'Maine': 2, 'is': 5, 'first': 2, 'state': 1, 'nation': 1, 'put': 3, 'expansion': 1, 'health': 1, 'insurance': 1, 'program': 1, 'ballot': 1, 'opening': 1, 'new': 3, 'front': 1, 'political': 2, 'battle': 1, 'over': 2, 'Obamacare': 1, 'Spain': 1, 'Moves': 2, 'Take': 1, 'Control': 2, 'Catalonia': 1, 'After': 5, 'Secession': 1, 'Vote': 1, 'RAPHAEL': 1, 'MINDER': 1, 'PATRICK': 1, 'KINGSLEY': 1, 'Shortly': 1, 'after': 1, 'Catalan': 1, 'leaders': 1, 'declared': 1, 'independence': 1, 'Spains': 1, 'leader': 1, 'fired': 1, 'Catalonias': 2, 'government': 3, 'dissolved': 1, 'regional': 2, 'parliament': 1, 'ordered': 2, 'elections': 1, 'Tired': 1, 'Years': 1, 'Separatist': 1, 'Strife': 1, 'Many': 1, 'Basques': 1, 'Wary': 2, 'Independence': 2, 'Bid': 1, 'Showdown': 1, 'Photographs': 1, 'Rwanda': 1, 'Using': 1, 'Plastic': 1, 'Bags': 1, 'Can': 5, 'Land': 1, 'You': 8, 'Prison': 1, 'KIMIKO': 1, 'de': 1, 'FREYTASTAMURA': 1, '500': 1, 'AM': 1, 'ET': 1, 'It': 4, 'illegal': 1, 'import': 1, 'produce': 1, 'use': 1, 'sell': 1, 'plastic': 1, 'bags': 1, 'country': 1, 'violators': 1, 'face': 3, 'stiff': 1, 'punishment': 1, 'But': 2, 'zero': 1, 'tolerance': 1, 'policy': 1, 'appears': 1, 'be': 3, 'paying': 1, 'off': 1, 'streets': 1, 'are': 1, 'spotless': 1, 'A': 14, 'Sick': 1, '10YearOld': 2, 'Center': 2, 'Immigration': 1, 'Debate': 1, 'VIVIAN': 1, 'YEE': 1, 'case': 1, 'girl': 1, 'with': 6, 'cerebral': 1, 'palsy': 1, 'who': 2, 'was': 4, 'brought': 1, 'illegally': 1, 'Texas': 1, 'so': 2, 'she': 1, 'could': 2, 'get': 6, 'medical': 1, 'care': 1, 'goes': 1, 'heart': 2, 'immigration': 1, 'debate': 1, 'Daily': 2, '360': 3, '205': 1, 'Where': 3, 'Made': 1, 'Sriracha': 1, 'Hot': 1, 'Sauce': 1, 'Sue': 1, 'Ding': 1, 'for': 20, 'Technology': 2, 'Samsung': 1, 'More': 10, 'Go ...

# %% [markdown]
# > - 먼저 IncrementalProject이라는 함수를 정의하는데, 이 함수는 URL 페이지의 소스의 순수 텍스트와 순수 텍스트 출현 빈도를 사전 형태로 출력하는 함수입니다. 과제 02번에서 했던 것처럼
#         f = request.urlopen(url)
#         source_bytes = f.read()
#         source = source_bytes.decode('utf-8')
#         text = ''
#     와 같은 방식으로 페이지의 소스 코드를 가져옵니다. <br><br>
# > - 다음으로는 소스 코드의 주석을 제거 하는데 html에서 주석은 ```<!--  -->```와 같은 형태이므로 index 함수를 통해
#     해당 문자열 ```<!--```이 감지된다면 감지된 인덱스를 left 변수에 저장하고,
#     문자열 ```-->```이 감지된다면 감지된 인덱스를 right 변수에 저장합니다.
#     소스 코드에서 주석은 무시해도 되는 부분이므로 위에서 URL 페이지의 소스를 담은
#     source 변수를 ```source[:left] + source[right+3:]```와 같이 변경합니다.<br><br>
# > - 위와 동일하게 html의 ```&nbsp; &quot; &lt; &gt; &amp;```에 대해서도 처리해줍니다.
#     해당 문자열이 감지된다면 문자열 슬라이싱을 이용하여 source 변수를 변경해줍니다. <br><br>
# > - 다음으로는 css 태그인 ```<style>```과 javascript 태그인 ```<script>```을 제거하는 부분입니다.
#     위와 마찬가지로 해당 태그가 감지된다면 문자열 슬라이싱을 이용하여 source 변수를 변경해줍니다. <br><br>
# > - 그리고 html 태그는 <와 >의 쌍으로 나타내어지므로 index 함수를 통해 해당 문자열이 감지된다면
#     순수 텍스트를 답는 text 변수에 < 문자가 감지되기 이전까지의 소스코드를 text에 덧붙여줍니다.
#     그리고 soruce는 > 문자가 감지된 이후부터로 갱신해주면 됩니다.<br><br>
# > - 마지막으로 구두문자를 제거하기 위한 방법입니다. 먼저 Python에서 제공하는 string 모듈의 punctuation을 부르면 Python에서 정의한 구두문자     를 볼 수 있습니다. 추가로 ```['’','‘','···','【','】','…','·','»','¢','£','¥','€','®','ⓒ','©']```와 같은 구두문자와 html entitiy 문자도 넣어주었습니다. <br><br>
#     그리고 for ~ in 문을 순수 문자열이 저장된 text에 단어 개수만큼 돌면서 해당 단어에 구두문자가 있으면 replace 함수를 통해
#     ''(아무 값도 존재 하지 않음)으로 바꿔줍니다.<br><br>
#     만약 replace된 단어의 길이가 0보다 크고 순수 텍스트와 순수 텍스트 출현 빈도를 저장하는 사전 wordList에 들어가 있지 않으면
#     해당 단어를 키 값으로 하는 벨류 값을 1로(처음 들어가는 것이므로) 줍니다.  반면에 replace된 단어의 길이가 0보다 크지만, 사전 wordList에 들어가 있으면 해당 단어를 키 값으로 하는 벨류 값을 1 증가시켜줍니다.

# %% [markdown]
# ---
# 소감 : 과제가 계속해서 어려워지는 것을 느낍니다. 특히 이번 Incremental Project은 접근하는 방식에 따라 코드 길이 차이가 확연히 났습니다. 처음에는 위와 같이 하지 않고 페이지 소스의 모든 문자를 하나씩 for 문으로 접근해가며 검사하는 방식을 사용하였는데, 멤버쉽 테스트 in을 사용하면 쉽게 문제를 풀 수 있다는 것을 알았습니다. 파이썬을 공부하면서 파이썬에서 제공하는 문법을 제대로 알지 못하면 자칫 복잡하게 코드를 작성할 수 있다는 생각을 하게 되었습니다. 더욱더 개념에 충실해야겠다는 생각을 했으며, 아직 제가 많이 부족하다는 생각도 많이 하였습니다.
# 이제 중간고사도 다가오는데 처음에 결심했던 것처럼 열심히 공부해야겠다는 생각을 다시 한번 하게 됩니다...
#
# ---
