# %% [markdown]
# ## Assignment 5

# %% [markdown]
# ---
# <b>한국기술교육대학교 컴퓨터공학부<br>
# 스크립트 프로그래밍(Script Programming)<br>
# 2014136129 최은빈
# ___

# %% [markdown]
# ### 1번 문제

# %% [markdown]
# 클래스와 모듈의 공통점과 차이점에 대해 설명하시오.

# %% [markdown]
# > - 공통점으로는 둘 다 독립된 이름 공간을 사용할 수 있으며 서로 연관된 코드를 묶어 독립성을 유지하며 재사용할 수 있게 합니다.
# > - 차이점으로는 클래스는 클래스 영역 내에 이름 공간을 구성하지만, 모듈은 파일 단위로 이름 공간을 구성합니다.

# %% [markdown]
# ### 2번 문제

# %% [markdown]
# 다형성에 대해 설명하고 다형성을 보여주는 자신만의 파이썬 코드 예제를 제시하시오.

# %% [markdown]
# > - 다형성은 상속 관계 내의 다른 클래스들의 인스턴스들이 같은 멤버 함수 호출에 대해 각각 다르게 반응하도록 하는 기능입니다. 예를 들어 연산자 오버로딩도 다형성을 지원하는 중요 기술로 a와 b의 객체 형에 따라 a + b의 + 연산자 행동 방식이 변경되는 것입니다. <br><br>
# > - 다형성의 장점으로는 적은 코딩으로 다양한 객체들에게 유사한 작업을 수행시킬 수 있고 프로그램 작성 코드량이 줄어듭니다. 또한 코드의 가독성을 높혀줍니다. <br><br>
# > - 형 선언이 없다는 점에서 파이썬에서 다형성을 적용하기에 더욱 용이하고, 실시간으로 객체의 형이 결정되므로 단 하나의 메소드에 의해 처리될 수 있는 객체의 종류에 제한이 없어 다른 언어보다 코드의 양이 줄어듭니다. <br><br>

# %%
# 다형성에 관한 예제

# 가장 상위 부모 클래스
class Instrument:  
    def play(self):
        print('Instrument')
    
# 자식 클래스
class Piano(Instrument): 
    def play(self):
        print('Piano - 도레미파솔')
        
class Drum(Instrument):
    def play(self):
        print('Drum - 두구두구두구')
    
class Trumpet(Instrument): 
    def play(self):
        print('Trumpet - 빰빰빰')
              
class Pansori(Instrument): 
    def play(self):
        print('Pansori - 얼씨구 절씨구')
        
class Guitar(Instrument):
    pass
        

# for 루프
for each in (Piano(), Drum(), Trumpet(), Pansori(), Guitar()):
    each.play()
# Out:
# Piano - 도레미파솔
# Drum - 두구두구두구
# Trumpet - 빰빰빰
# Pansori - 얼씨구 절씨구
# Instrument

# %% [markdown]
# > - 위 코드는 제가 작성한 다형성을 보여주는 코드입니다. Instrument 클래스를 상속받은 Piano, Drum, Trumpet, Pansori, Guitar 클래스에서는 Instrument 클래스의 play 메소드를 오버라이딩합니다. 여기서 Guitar 클래스에서는 play 메소드가 오버라이딩 되지 않았으므로 Instrument 클래스의 play 메소드를 가져다 사용합니다.

# %% [markdown]
# ### 3번 문제

# %% [markdown]
# 다음 각 요구사항 모두를 만족시키는 Counter 클래스를 코딩하시오 (정답을 각 요구사항별로 입력할 필요 없이 3번 문제에 대해 1개의 클래스 정의 코드를 제시하면 된다.)

# %% [markdown]
# - 요구사항 1. 생성자에 count 값과 step 값을 인자로 받을 수 있다.
#     - count : Counter 인스턴스가 지니는 초기 정수 값
#     - step: Counter 인스턴스의 count가 증가되는 증분 (defalt 값: 1)
#     > ```>>> c = Counter(10)``` <br>
#     > ```>>> d = Counter(10, 2)``` <br>

# %% [markdown]
# - 요구사항 2. 다음과 같이 Counter의 인스턴스를 출력을 해주는 ```__str__()``` 메소드를 Counter 클래스 내에 구현하시오.
#     > ```>>> print(c)
# [Count (step: 1)] 10 ``` <br>
#     > ```>>> print(d)
# [Count (step: 2)] 10 ```

# %% [markdown]
# - 요구사항 3. 다음과 같이 step에 주어진 증분만큼 count를 증가시키는 incr() 메소드를 Counter 클래스 내에 구현하시오.
#     > ```>>> c.incr() ```<br>
#     > ```>>> d.incr() ``` <br>
#     > ```>>> print(c)
# [Count (step: 1)] 11 ```<br>
#     > ```>>> print(d)
# [Count (step: 2)] 12``` <br>

# %% [markdown]
# - 요구사항 4. Counter 클래스 내에 관련 메소드를 추가하여 인스턴스 객체를 직접 호출(call)할 수 있도록 하시오. 인스턴스 객체를 직접 호출했을 때에 내부적으로 incr() 메소드를 호출하는 방법으로 구현하시오.
#     > ```>>> c()``` <br>
#     > ```>>> d()``` <br>
#     > ```>>> print(c)
# [Count (step: 1)] 12 ```<br>
#     > ```>>> print(d)
# [Count (step: 2)] 14 ```

# %% [markdown]
# - 요구사항 5. 다음과 같은 두 개의 산술 연산 (+, -)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#     > ```>>> c = c + 5``` <br>
#     > ```>>> d = d - 5``` <br>
#     > ```>>> print(c)
# [Count (step: 1)] 17 ```<br>
#     > ```>>> print(d)
# [Count (step: 2)] 9 ```<br>

# %% [markdown]
# - 요구사항 6. 다음과 같은 관계연산 (>, <, ==)이 수행될 수 있도록 Counter 클래스 내에 관련 메소드를 추가하시오.
#     > ```>>> print(c > 10)
# True ```<br>
#     > ```>>> print(d > 10)
# False ```<br>
#     > ```>>> print(c < 10)
# False ```<br>
#     > ```>>> print(d < 10)
# True ```<br>
#     > ```>>> print(c == 17)
# True ```<br>
#     > ```>>> print(d != 9)
# False ```

# %%
class Counter():
    # 요구사항 1
    def __init__(self, count, step = 1):
        self.count = count
        self.step = step
        
    # 요구사항 2
    def __str__(self):
        return str('[Count (Step : %d)] %d' % (self.step, self.count))
    
    # 요구사항 3
    def incr(self):
        self.count += self.step
        
    # 요구사항 4
    def __call__(self):
        self.incr()
        
    # 요구사항 5
    def __add__(self, num):
        self.count += num
        return self
    
    def __sub__(self, num):
        self.count -= num
        return self
    
    # 요구사항 6
    def __gt__(self, num):
        return self.count > num
    
    def __lt__(self, num):
        return self.count < num
    
    def __eq__(self, num):
        return self.count == num
    
    def __ne__(self, num):
        return self.count != num

# %%
#요구사항1    
c = Counter(10)
d = Counter(10,2)

#요구사항2
print (c)
print (d)
print ()

#요구사항3
c.incr()
d.incr()
print (c)
print (d)
print ()

#요구사항4
c()
d()
print (c)
print (d)
print ()

#요구사항5
c = c + 5
d = d - 5
print (c)
print (d)
print ()

#요구사항6
print (c > 10)
print (d > 10)
print (c < 10)
print (d < 10)
print (c == 17)
print (d != 9)
# Out:
# [Count (Step : 1)] 10
# [Count (Step : 2)] 10
#
# [Count (Step : 1)] 11
# [Count (Step : 2)] 12
#
# [Count (Step : 1)] 12
# [Count (Step : 2)] 14
#
# [Count (Step : 1)] 17
# [Count (Step : 2)] 9
#
# True
# False
# False
# True
# True
# False

# %% [markdown]
# ### 4번 문제

# %% [markdown]
# 다음은 내장 자료형 list를 서브클래싱하여 만든 MySet 클래스 정의 내용이다. 다음 클래스 정의에서 ```__init__(), __str()__(), elimicate_duplicate()```의 세 개의 메소드 코드 내용을 자신이 다른 사람에게 가르친다고 생각하며 설명해보시오.
#    - MySet은 집합(Set) 자료형을 정의하려는 의도하에 만들어진 클래스이다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)

        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %% [markdown]
# > - ```__init__()``` 메소드는 생성자 메소드로 MySet 클래스를 생성할 때 자동으로 호출됩니다. 생성할 때 인자로 받은 리스트의 원소들을 가지는 리스트를 만들고, 리스트를 만들 때에는 append 함수를 이용하였는데, 여기서 MySet 클래스는 list를 상속받았기 때문에 그 자체가 리스트이므로 append 함수의 사용이 가능합니다. 그리고 MySet 클래스를 이용하여 eliminate_duplicate 함수를 호출해주었습니다.  <br><br>
#
# > - ```__str__()``` 메소드는 출력할 때 이용하는 함수입니다. 먼저 출력 시 가장 앞에 나오는 "MySet: {" 문자열을 저장하고, 인자로 오는 리스트의 원소들을 문자열로 바꿔 변환해줄 문자열에 추가시줍니다. 리스트의 원소를 구분하기 위해 하나의 원소가 추가될 때마다 구분자 " ,"(띄어쓰기와 콤마)을 추가시켜주었고, 모든 원소들을 추가시켜준 뒤에는 마지막에 붙는 " ,"(띄어쓰기와 콤마) 문자가 필요 없으므로 슬라이싱을 이용하여 제거해주었습니다. 마지막에는 } 문자열을 추가시켜주었고, 이렇게 변환된 문자열을 반환하였습니다.<br><br>
#
#
# > - ```eliminate_duplicate()``` 메소드는 인자로 들어온 리스트에서 중복된 원소들을 제거해주는 함수입니다. 먼저 빈 리스트(s)를 만들어 인자로 들어온 리스트(l)의 원소가 리스트(s)에 존재하지 않으면 리스트(s)에 추가시켜줍니다. 그리고 인자로 들어온 리스트(l)를 비워주고, 인자로 들어왔던 리스트(l)에 만들어 두었던 리스트(s)의 원소를 차례로 추가시켜주면 중복된 원소가 제거된 리스트를 만들 수 있습니다. 여기서 그냥 중복을 제거한 리스트를 반환하는 것이 아니라 중복을 제거한 리스트(s)를 다시 인자로 들어온 리스트(l)에 넣어주기 때문에 이 함수에는 반환값이 존재하지 않는다는 것을 알 수 있습니다. 즉, eliminate_duplicate(self) 만으로도 self는 중복이 제거된 리스트가 됩니다. 또한 이 메소드는 정적 메소드로 선언되었기 때문에 인스턴스 객체가 아니여도 클래스 이름만으로 호출할 수 있습니다.<br><br>

# %% [markdown]
# ### 5번 문제

# %% [markdown]
# 4번 문제에 정의된 MySet 클래스에 메소드를 추가하여 다음 각 요구사항 모두를 만족시키는 코딩을 제시하시오.
# - 정답을 각 요구사항별로 입력할 필요 없이 요구사항 3개 전체에 대해 1개의 MySet 클래스 정의 코드를 제시하고 주석등으로 해당 코드를 설명한다.
# - 요구사항 1. | 연산으로 두 집합의 합집합을 반환한다.
#
#     > ```>>> u = s | t``` <br>
#     > ```>>> print(u)``` <br>
#     > ```MySet: {1, 2, 3, 4, 5, 6, 7, 8, 9}``` <br>
# - 요구사항 2. & 연산으로 두 집합의 교집합을 반환한다.
#
#     > ```>>> u = s & t ```<br>
#     > ```>>> print(u) ```<br>
#     > ```MySet: {2, 3} ```<br>
# - 요구사항 3. - 연산으로 두 집합의 차집합을 반환한다.
#
#     > ```>>> s = MySet([1, 2, 3])``` <br>
#     > ```>>> t = MySet([3, 4, 5]) ```<br>
#     > ```>>> u = s - t ```<br>
#     > ```>>> print(u) ```<br>
#     > ```MySet: {1, 2} ```<br>

# %% [markdown]
# 이 문제를 풀기위해 리스트에는 ```__or__, __and__, __sub__```가 내장되어있지 않기 때문에 기존에 리스트 자료형을 집합 자료형으로 변경하였습니다.

# %%
class MySet(set):
    def __init__(self, l):
        for e in l:
            self.add(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = set()
        for e in l:
            if e not in s:
                s.add(e)

        l.clear()
        for e in s:
            l.add(e)

    # 요구사항 1
    def __or__(self, l):
        s = set()
        # self와 l를 합친 다음
        for e in self: 
            s.add(e)
        for e in l:
            s.add(e)
        MySet.eliminate_duplicate(s) # 중복 제거
        return s
    
    # 요구사항 2
    def __and__(self, l):
        s = set()
        for e in self:
            if e in l:
                s.add(e) # self와 l에 공통으로 있는 맴버만 추가
        return s
    
    # 요구사항 3
    def __sub__(self, l):
        s = set()
        for e in self:
            if e not in l:
                s.add(e) # self에는 있지만 l에는 없는 원소만 추가
        return s
    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print (s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print (t)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}

# %%
u = s | t
print (u)

u = s & t
print (u)

s = MySet([1, 2, 3]) 
t = MySet([3, 4, 5]) 
u = s - t 
print (u)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {2, 3}
# {1, 2}

# %% [markdown]
# > - 먼저 ```__or__()``` 메소드는 집합(set) 자료구조를 가지는 객체 s에 반복문을 돌면서 첫번째 인자로 들어온 set 객체의 원소와 두번째 인자로 들어온 set 객체의 원소를 모두 add 함수를 불러 추가시켜줍니다. 그리고 클래스의 eliminate_duplicate() 메소드를 불러 중복을 제거해줍니다. (자료구조 자체를 집합(set)을 이용하기 때문에 중복제거가 되지만, 명시적으로 표시해준 것임) <br><br>
# > - 그리고 ```__and__()``` 메소드는 집합(set) 자료구조를 가지는 객체 s에 반복문을 돌면서 첫번째 인자로 들어온 set 객체의 원소가 두번째 인자로 들어온 set 객체 원소로 존재할 경우에만 add 함수를 불러 추가시켜줍니다. <br><br>
# > - ```__sub__()``` 메소드는 메소드는 집합(set) 자료구조를 가지는 객체 s에 반복문을 돌면서 첫번째 인자로 들어온 set 객체의 원소가 두번째 인자로 들어온 set 객체 원소로 존재하지 않을 경우에만 add 함수를 불러 추가시켜줍니다.<br><br>

# %% [markdown]
# > - [참고] 이 문제를 풀기 위해 기존에 리스트 자료형을 집합 자료형으로 변경하였습니다. 그 이유는 리스트에``` __or__, __and__, __sub__ ```함수가 내장되어있지 않기 때문입니다. 아래의 코드에서 ``` __or__, __and__, __sub__ ```함수가 내장되어있지 않다는 것을 알 수 있습니다.

# %%
print(dir(list)) # __or__, __and__, __sub__ 존재하지 않음
print()
print(dir(set)) # __or__, __and__, __sub__ 존재험
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']
#
# ['__and__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %% [markdown]
# > - 따라서 집합 자료형으로 모두 변경해주었고, 4번의 MySet에서 리스트의 append는 집합의 add로, 21번째 줄의 l[:] = []을 l.clear()으로 변경해주었고, 기존에 리스트 자료구조를 사용하였던 객체들을 모두 set() 키워드로 집합 자료형으로 생성해주었습니다.

# %% [markdown]
# ### 6번 문제

# %% [markdown]
# 5번 문제에서 정의한 MySet 클래스에 대해 다음 예제를 수행하면 오류없이 올바르게 동작하는 것을 확인할 수 있다. 다음 예제 내에 있는 len(), bool() 내장함수와 in 키워드 사용 예제가 별다른 메소드 정의를 하지 않았는 데도 올바르게 수행되는 이유를 설명하시오.

# %% [markdown]
# ``` >>> s = MySet([1, 2, 3, 4, 5, 6]) ``` <br>
# ```>>> print(len(s))```<br>
# ```> 6```<br>
# ```>>> print(bool(s))```<br>
# ```> True```<br>
# ```>>> print(2 in s)```<br>
# ```> True ```<br>

# %% [markdown]
# > - 먼저 코드를 통해 오류없이 올바르게 작동하는 것을 확인하였습니다.

# %%
class MySet(list):
    def __init__(self, l):
        for e in l:
            self.append(e)
        MySet.eliminate_duplicate(self)
    
    def __str__(self):
        result = "MySet: {"
        for e in self:
            result = result + str(e) + " ,"
        result = result[0:len(result)-2] + "}"
        return result

    @staticmethod    
    def eliminate_duplicate(l):
        s = []
        for e in l:
            if e not in s:
                s.append(e)
        l[:] = []
        for e in s:
            l.append(e)

    
if __name__ == "__main__":
    s = MySet([1, 2, 2, 3])
    print(s)
    t = MySet([2, 3, 4, 5, 6, 7, 8, 8, 8, 8, 8, 9])
    print(t)
    
u = MySet([1, 2, 3, 4, 5, 6]) 
print(len(u))
print(bool(u))
print(2 in u)
# Out:
# MySet: {1 ,2 ,3}
# MySet: {2 ,3 ,4 ,5 ,6 ,7 ,8 ,9}
# 6
# True
# True

# %% [markdown]
# > - len()이나 bool()은 내장함수로 별도의 모듈 추가 없이 기본적으로 제공되며, 이름 공간에 명시적으로 들어올 필요 없이 언제든지 사용할 수 있는 것이기 때문에 오류가 나지 않습니다. 아래의 코드는 리스트의 내장함수가 무엇이 있는지 확인해보는 것입니다.<br>

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# > - 아래 실행과 같이 in은 예약어입니다. 따라서 프로그램 내에서 특정한 역할을 수행하도록 하기 위해 파이썬 언어가 미리 예약해둔 것이기 때문에 사용해도 에러가 나지 않습니다.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 7번 문제

# %% [markdown]
# 이전 Assignment 3 (Assignment 4가 아님)의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하여 각 단어들에 대해 출현빈도를 사전형태({'world': 2, 'hello': 1, 'python': 1})로 저장하여 출력하는 것이었다. 이번에는 Assignment 3을 다시 확장/변형하여 다음과 같은 조건을 만족하도록 구현하시오.

# %% [markdown]
# - 1) 새로운 클래스 WebWordsFrequency를 정의하시오.
#     - 이전 Assignment 4에서 고려했던 pickle 모듈등은 전혀 고려하지 마시오.
#         - 즉, 하드디스크에 저장하고 다시 로드하는 기능은 본 숙제에는 배제하시오.
#     - Assignment 4에서 고려했던 영어 불용어 처리는 적용하시오.
#     - Assignment 4에서 처럼 국문 사이트가 아닌 영어 사이트만을 고려하여 아래 사항을 코딩하시오.

# %% [markdown]
# - 2) 생성자에 URL을 0개에서 임의의 개수를 넣을 수 있도록 생성자 인수를 가변인수로 정의하여 각각의 URL을 리스트 자료형에 유지하시오.

# %% [markdown]
# > ```>>> w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'https://www.amazon.com') ```<br>
# > ```>>> w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com') ```<br>
# > ```>>> w3 = WebWordsFrequency() ```<br>

# %% [markdown]
# - 3) addUrl() 메소드를 구현하여 인스턴스를 생성한 이후에도 URL을 추가할 수 있도록 한다.
#     - 반드시 1개의 URL을 추가하도록 구현 (즉, 동시에 여러 개의 URL을 추가하는 것은 배제)
#     > ```>>> w1.addUrl('https://github.com')```<br>
#     > ```>>> w3.addUrl('http://stackoverflow.com')```

# %% [markdown]
# - 4) removeUrl() 메소드를 구현하여 URL을 삭제할 수 있도록 한다.
#     - 반드시 1개의 URL을 삭제하도록 구현 (즉, 동시에 여러 개의 URL을 삭제하는 것은 배제)
#     > ```>>> w1.removeUrl('http://www.cnn.com')```<br>
#     > ```>>> w2.removeUrl('http://stackoverflow.com')```

# %% [markdown]
# - 5) listUrls() 메소드를 구현하여 현재 등록된 모든 URL을 출력하는 기능을 추가
# > ```>>> w1.listUrls()```<br>
# > http://www.times.com <br>
# > https://www.amazon.com <br>
# > https://github.com <br>

# %% [markdown]
# - 6) getWordsFrequency() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전을 반환하시오.
#     - 만약 등록된 URL이 없다면 공백 사전을 반환
#     > ```>>> w1.getWordsFrequency()
# {'hello': 8, 'site': 12, 'world': 2, 'science': 11, 'program': 1, 'python': 1}```

# %% [markdown]
# - 7) getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환하시오.
# > ```>>> w1.getMaxFreqencyWords()
# site ```
#
#
# - 최다 출현 단어의 빈도수가 동일한 경우 모두 출력해주어야 함
# > ```>>> w2.getMaxFreqencyWords() ```<br>
# > site <br>
# > science <br>
#     - 만약 등록된 URL이 없다면 None을 반환

# %% [markdown]
# - 8) 임의의 단어 1개를 파라미터로 받는 searchUrlByWord() 메소드를 구현하여 유사도가 높은 웹 사이트를 출력하시오.
# > ```>>> w1.searchUrlByWord("news")
# http://www.cnn.com ```
#
#     - 파라미터로 받은 단어와 유사도가 동일한 URL이 여러 개이면 해당 URL을 모두 출력하시오.

# %%
from urllib import request 
import string

class WebWordsFrequency:
    def __init__(self, *l):
        self.urlList = []
        self.words = {}
        for url in l:
            self.addUrl(url)
    
    def addUrl(self, url):
        self.getWords(url)
        self.urlList.append(url)
        
    def removeUrl(self, url):
        if url in self.urlList:
            del self.words[url]
            self.urlList.remove(url)
    
    def listUrls(self):
        for url in self.urlList:
            print (url)
    
    def getWords(self, url):
        self.words[url] = {}
        source = request.urlopen(url).read().decode('utf-8')
        text = ''
        
        while ('<!--' in source):
            # 주석은 <!-- 과 --> 의 쌍으로 나타내어지므로 index 함수를 사용해 주석을 찾아 없앤다
            left = source.index('<!--')
            right = source.index('-->')
            source = source[:left] + source[right+3:]
        
        # Html Entities 제거
        htmlEntities = ['&nbsp;','&quot;','&lt;','&gt;','&amp;']
        for entity in htmlEntities:
            while (entity in source):
                left = source.index(entity)
                right = source.index(entity)
                source = source[:left] + source[right+len(entity):]    
        
        # <script> 태그가 없어질때까지 반복 (javascript 태그)
        while ('<script' in source):
        # <script> 태그 뒤에는 문장이 올 수 있으므로 <script 으로 검사해준다 
        # <script> ~ </script> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
            left = source.index('<script')
            right = source.index('</script>')
            source = source[:left] + source[right+9:]
    
        # <style> 태그가 없어질때까지 반복 (css 태그)
        while ('<style' in source):
        # <style> 태그 뒤에는 문장이 올 수 있으므로 <style 으로 검사해준다 
        # <style> ~ </style> 사이에 오는 문장은 순수 텍스트가 아니므로 무시한다
            left = source.index('<style')
            right = source.index('</style>')
            source = source[:left] + source[right+8:] 
    
        # 태그는 < 과 > 의 쌍으로 나타내어지므로 index 함수를 사용해 태그 부분을 찾아 없앤다
        while('<' in source):
            left = source.index('<')
            right = source.index('>')
            text = text + ' ' + source[:left]
            source = source[right+1:]
            
        # 구두 문자 추가
        puncList = list(string.punctuation)
        puncList.extend(['’','‘','···','【','】','…','·','»','¢','£','¥','€','®','ⓒ','©']) 
        stopword = "a,about,above,across,after,again,against,all,almost,alone,along,already,also,although,always,among,an,and,another,any,anybody,anyone,anything,anywhere,are,area,areas,around,as,ask,asked,asking,asks,at,away,b,back,backed,backing,backs,be,became,because,become,becomes,been,before,began,behind,being,beings,best,better,between,big,both,but,by,c,came,can,cannot,case,cases,certain,certainly,clear,clearly,come,could,d,did,differ,different,differently,do,does,done,down,down,downed,downing,downs,during,e,each,early,either,end,ended,ending,ends,enough,even,evenly,ever,every,everybody,everyone,everything,everywhere,f,face,faces,fact,facts,far,felt,few,find,finds,first,for,four,from,full,fully,further,furthered,furthering,furthers,g,gave,general,generally,get,gets,give,given,gives,go,going,good,goods,got,great,greater,greatest,group,grouped,grouping,groups,h,had,has,have,having,he,her,here,herself,high,high,high,higher,highest,him,himself,his,how,however,i,if,important,in,interest,interested,interesting,interests,into,is,it,its,itself,j,just,k,keep,keeps,kind,knew,know,known,knows,l,large,largely,last,later,latest,least,less,let,lets,like,likely,long,longer,longest,m,made,make,making,man,many,may,me,member,members,men,might,more,most,mostly,mr,mrs,much,must,my,myself,n,necessary,need,needed,needing,needs,never,new,new,newer,newest,next,no,nobody,non,noone,not,nothing,now,nowhere,number,numbers,o,of,off,often,old,older,oldest,on,once,one,only,open,opened,opening,opens,or,order,ordered,ordering,orders,other,others,our,out,over,p,part,parted,parting,parts,per,perhaps,place,places,point,pointed,pointing,points,possible,present,presented,presenting,presents,problem,problems,put,puts,q,quite,r,rather,really,right,right,room,rooms,s,said,same,saw,say,says,second,seconds,see,seem,seemed,seeming,seems,sees,several,shall,she,should,show,showed,showing,shows,side,sides,since,small,smaller,smallest,so,some,somebody,someone,something,somewhere,state,states,still,still,such,sure,t,take,taken,than,that,the,their,them,then,there,therefore,these,they,thing,things,think,thinks,this,those,though,thought,thoughts,three,through,thus,to,today,together,too,took,toward,turn,turned,turning,turns,two,u,under,until,up,upon,us,use,used,uses,v,very,w,want,wanted,wanting,wants,was,way,ways,we,well,wells,went,were,what,when,where,whether,which,while,who,whole,whose,why,will,with,within,without,work,worked,working,works,would,x,y,year,years,yet,you,young,younger,youngest,your,yours".split(',')
    
        for t in text.split(): # 현재 text에 들어 있는 문장은 순수 텍스트이므로 공백을 기준으로 자름
            for char in puncList: 
                t = t.replace(char, '')
            t = t.lower() # 모든 단어를 대소문자를 구분하지 않고 단어를 저장함
            if len(t) > 0 and not t in stopword:
                if not t in self.words[url].keys():
                    self.words[url][t] = 1
                else:
                    self.words[url][t] += 1

    
    def getWordsFrequency(self):
        if len(self.urlList) == 0:
            return {}
        
        totalWords = {} 
        for url, word in self.words.items():
            for tmp in word.keys():
                if not tmp in totalWords.keys():
                    totalWords[tmp] = word[tmp]
                else:
                    totalWords[tmp] += word[tmp]
        
        return totalWords
    
    
    def getMaxFreqencyWords(self):
        if len(self.urlList) == 0:
            return None
        
        totalWords = self.getWordsFrequency()
        tmp = []
        maxv = 0
        for word, cnt in totalWords.items():
            if cnt > maxv:
                maxv = cnt
            
        for word, cnt in totalWords.items():
            if cnt == maxv:
                tmp.append(word)
        return tmp
    
    
    def searchUrlByWord(self, keyword):
        temp = []
        similarity = {}
        print("\n")
        print ("[ KEYWORD : %s ]" % (keyword))
        print("--------------------------------------\n")
        for i in range(len(self.urlList)):
            
           # print(self.words[self.urlList[i]])
            temp = list(self.words[self.urlList[i]].keys())
            if keyword in temp:
                similarity[self.urlList[i]] = 10 # 기본 유사도를 10으로 줌
            
                print ("URL : " + self.urlList[i])
                print ("키워드 %s 가 포함된 단어 항목입니다\n" % (keyword))
                
                for j in range(len(temp)):
                    if temp[j].find(keyword) != -1 and temp[j] != keyword:
                        print("[word] %s : [similarity] %d" % (temp[j], self.words[self.urlList[i]][temp[j]]))
                        similarity[self.urlList[i]] += self.words[self.urlList[i]][temp[j]]
                    # 입력받은 키워드가 단어 일부일 경우, 해당 단어의 출현 빈도를 더해줌
        
                    elif temp[j] == keyword:
                        print("[word] %s : [similarity] %d" % (temp[j], self.words[self.urlList[i]][temp[j]] + 20))
                        similarity[self.urlList[i]] += (self.words[self.urlList[i]][temp[j]] + 20) 
                    # 입력받은 키워드가 단어와 같을 경우에는, 해당 단어의 출현 빈도에 보너스 점수 20을 더한 것을 더해줌
                print("--------------------------------------")
            else:
                print ("URL : " + self.urlList[i])
                print ("키워드 %s 가 존재하지 않습니다\n" % (keyword))
                print("--------------------------------------")    
            
        
        maxv = 0
        l = []
        for url, count in similarity.items():
            if count > maxv:
                maxv = count;
        # 리스트에 저장
        for url, count in similarity.items():
            if count == maxv:
                l.append(url)
                
        print("=>" , end = ' ')
        return l

# %%
# 인스턴스 생성
w1 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com', 'http://www.apple.com/')
w2 = WebWordsFrequency('http://www.cnn.com', 'http://www.times.com')
w3 = WebWordsFrequency()

# add 테스트
w1.addUrl('https://github.com')
w3.addUrl('http://stackoverflow.com')

# remove 테스트
w1.removeUrl('http://www.cnn.com')
w2.removeUrl('http://stackoverflow.com')

# listUrls 테스트
w1.listUrls()
print ()
w2.listUrls()
print ()
w3.listUrls()
print ()
print ()

# getWordsFrequency 테스트
print (w1.getWordsFrequency())
print ()
print ()
print (w2.getWordsFrequency())
print ()
print ()
print (w3.getWordsFrequency())
print ()

# getMaxFreqencyWords 테스트
print (w1.getMaxFreqencyWords())
print ()
print (w2.getMaxFreqencyWords())
print ()
print (w3.getMaxFreqencyWords())
print ()

# searchUrlByWord 테스트
print (w1.searchUrlByWord("news"))
print ()
print (w1.searchUrlByWord('apple'))
# Out:
# http://www.times.com
# http://www.apple.com/
# https://github.com
#
# http://www.cnn.com
# http://www.times.com
#
# http://stackoverflow.com
#
#
# {'york': 12, 'times': 16, 'breaking': 1, 'news': 10, 'world': 7, 'multimedia': 2, 'nytimescom': 3, 'supports': 1, 'internet': 2, 'explorer': 1, '9': 1, 'earlier': 1, 'please': 1, 'upgrade': 2, 'browser': 1, 'learn': 9, 'sections': 4, 'search': 8, 'skip': 3, 'content': 2, 'navigation': 8, 'subscribe': 5, 'log': 1, '0': 1, 'settings': 1, 'english': 2, '中文': 1, 'chinese': 1, 'español': 1, 'saturday': 1, 'december': 2, '2': 2, '2017': 8, 'todays': 5, 'paper': 2, 'video': 6, 'quick': 2, 'site': 11, 'politics': 3, 'ny': 2, 'business': 14, 'opinion': 10, 'tech': 2, 'science': 4, 'health': 6, 'sports': 4, 'arts': 6, 'style': 5, 'food': 4, 'travel': 6, 'magazine': 7, 'real': 4, 'estate': 4, 'close': 9, 'text': 1, 'input': 1, 'mobile': 3, 'top': 3, 'republican': 4, 'tax': 13, 'bill': 6, 'clears': 1, 'senate': 3, 'holdouts': 1, 'support': 3, 'sweeping': 1, 'overhaul': 1, 'decades': 1, 'jim': 1, 'tankersley': 1, 'thomas': 1, 'kaplan': 1, 'alan': 2, 'rappeport': 1, '542': 1, 'am': 8, 'et': 7, 'plan': 3, 'affects': 1, 'families': 1, 'owners': 1, 'multinational': 1, 'corporations': 1, 'biggest': 2, 'benefits': 1, 'flowing': 1, 'highestearning': 1, 'americans': 1, 'lawmakers': 1, 'received': 1, 'nearly': 1, '500page': 1, 'containing': 1, 'significant': 1, 'changes': 1, 'hours': 4, 'planned': 2, 'vote': 2, 'prompting': 1, 'outcry': 3, 'democrats': 1, 'voted': 1, 'hasty': 2, 'handscribbled': 2, 'sets': 2, 'gains': 1, 'economists': 1, 'heres': 3, 'help': 8, 'deciphering': 1, 'gop': 2, 'ohio': 1, 'met': 3, 'ambivalence': 1, 'majority': 1, 'leader': 1, 'mitch': 1, 'mcconnell': 1, 'walked': 1, 'chamber': 1, 'conference': 1, 'fellow': 1, 'republicans': 3, 'friday': 1, 'credit': 2, 'tj': 1, 'kirkpatrick': 1, 'analysis': 3, 'deficit': 2, 'priority': 1, 'takes': 1, 'seat': 1, 'cuts': 2, 'binyamin': 1, 'appelbaum': 1, 'party': 1, 'criticized': 1, 'growth': 2, 'president': 7, 'barack': 1, 'obama': 1, 'cut': 3, 'send': 3, 'heights': 1, 'win': 1, 'political': 3, 'lift': 1, 'carl': 1, 'hulse': 1, 'sheryl': 2, 'gay': 4, 'stolberg': 2, '151': 1, 'muchneeded': 1, 'victory': 1, 'remains': 2, 'seen': 1, 'raises': 1, 'ditch': 1, 'flynn': 9, 'pleads': 2, 'guilty': 6, 'lying': 1, 'fbi': 1, 'nyt': 3, 'extrump': 1, 'aide': 1, 'cooperating': 1, 'russia': 5, 'inquiry': 1, 'michael': 4, 'shear': 1, 'adam': 1, 'goldman': 1, 'plea': 5, 'trumps': 5, 'former': 5, 'national': 2, 'security': 8, 'adviser': 2, 'brings': 2, 'investigation': 2, 'russian': 3, 'interference': 1, '2016': 2, 'election': 2, 'inner': 2, 'circle': 2, 'flynns': 6, 'discussions': 1, 'sergey': 1, 'kislyak': 1, 'ambassador': 1, 'effort': 1, 'aides': 1, 'create': 3, 'foreign': 1, 'policy': 5, 'power': 2, 'documents': 2, 'comments': 9, 'charges': 2, 'court': 1, 'left': 1, 'react': 1, 'attorney': 1, 'eldest': 1, 'son': 1, 'soninlaw': 1, 'longtime': 1, 'lawyer': 2, 'campaign': 3, 'advisers': 1, 'chairman': 2, 'ties': 2, 'binding': 1, 'trump': 11, 'officials': 4, 'jasmine': 1, 'lee': 1, 'karen': 1, 'yourish': 1, 'eight': 1, 'people': 5, 'corresponded': 1, 'transition': 1, 'white': 6, 'house': 8, 'memo': 2, 'cooperation': 1, 'casts': 1, 'pall': 1, 'peter': 1, 'baker': 2, 'maggie': 1, 'haberman': 1, 'legal': 2, 'danger': 1, 'uncertain': 1, 'wrought': 1, 'grievous': 1, 'damage': 3, 'administration': 2, '332': 1, 'led': 1, 'niraj': 1, 'chokshi': 1, 'robin': 1, 'stein': 1, 'ainara': 1, 'tiefenthäler': 1, 'shane': 1, 'oneill': 1, 'roy': 3, 'moore': 3, 'rival': 2, 'afar': 2, 'gloria': 3, 'allred': 3, 'jess': 2, 'bidgood': 1, 'blinder': 1, 'fights': 1, 'claims': 1, 'sexual': 3, 'misconduct': 1, 'candidate': 1, 'alabama': 1, 'vilified': 1, 'representing': 1, 'accuser': 1, 'taxpayer': 1, 'funds': 1, 'covered': 1, 'harassment': 3, 'settlement': 1, 'yamiche': 1, 'alcindor': 1, '1222': 1, 'rep': 1, 'blake': 1, 'farenthold': 1, 'texas': 1, 'settled': 1, 'suit': 1, '84000': 1, 'six': 2, 'settlements': 1, 'funded': 1, 'taxpayers': 1, '2013': 1, 'firing': 3, 'lauer': 3, 'nbc': 3, 'control': 2, 'john': 2, 'koblin': 1, 'competitor ...
#
#
# {'cnn': 11, 'breaking': 3, 'news': 15, 'world': 10, 'weather': 3, 'entertainment': 2, 'video': 14, 'home': 6, 'regions': 3, 'politics': 6, 'money': 2, 'tech': 5, 'sport': 3, 'travel': 7, 'style': 6, 'health': 9, 'vr': 3, 'live': 2, 'tv': 5, 'search': 8, 'raquo': 34, 'international': 11, 'edition': 9, 'arabic': 4, 'español': 4, 'set': 5, 'preference': 4, 'confirm': 4, 'africa': 4, 'americas': 2, 'asia': 2, 'china': 5, 'europe': 2, 'middle': 2, 'east': 2, 'opinion': 12, '45': 2, 'congress': 2, 'security': 6, 'nine': 2, 'trumpmerica': 2, 'business': 11, 'markets': 2, 'luxury': 4, 'stars': 2, 'screen': 2, 'binge': 2, 'culture': 4, 'media': 3, 'gadgets': 2, 'future': 4, 'startups': 2, 'football': 3, 'tennis': 3, 'equestrian': 2, 'golf': 2, 'judo': 2, 'horse': 2, 'racing': 2, 'motorsport': 2, 'sailing': 3, 'skiing': 2, 'olympics': 2, 'destinations': 2, 'food': 6, 'drink': 2, 'play': 5, 'stay': 2, 'videos': 3, 'arts': 8, 'design': 3, 'fashion': 4, 'architecture': 3, 'autos': 2, 'diet': 2, 'fitness': 2, 'living': 4, 'parenting': 2, 'family': 3, 'vital': 2, 'signs': 2, 'features': 4, 'freedom': 2, 'project': 2, 'impact': 2, 'inside': 3, '2': 4, 'degrees': 2, 'heroes': 2, 'feature': 3, 'hln': 2, 'schedule': 2, 'worldwide': 2, 'cnnvr': 2, 'watch': 2, 'archives': 2, 'profiles': 2, 'leadership': 2, 'pressroom': 2, 'partner': 2, 'sites': 2, 'ireport': 2, 'espantildeol': 1, 'facebook': 2, 'twitter': 1, 'instagram': 1, 'copy2017cablenewsnetwork': 1, 'turnerbroadcastingsysteminc': 1, 'allrightsreserved': 1, 'cnnsanstradecopy2016cablenewsnetwork': 1, 'terms': 3, 'privacy': 2, 'policy': 3, 'adchoices': 1, 'msa': 1, 'statement': 1, 'advertise': 2, 'store': 2, 'newsletters': 2, 'help': 4, 'transcripts': 1, 'license': 1, 'footage': 1, 'newsource': 1, 'york': 12, 'times': 16, 'multimedia': 2, 'nytimescom': 3, 'supports': 1, 'internet': 2, 'explorer': 1, '9': 1, 'earlier': 1, 'please': 1, 'upgrade': 2, 'browser': 1, 'learn': 2, 'sections': 4, 'skip': 2, 'content': 1, 'navigation': 8, 'subscribe': 5, 'log': 1, '0': 1, 'settings': 1, 'english': 2, '中文': 1, 'chinese': 1, 'saturday': 1, 'december': 2, '2017': 6, 'todays': 5, 'paper': 2, 'quick': 2, 'site': 10, 'ny': 2, 'science': 4, 'sports': 4, 'magazine': 7, 'real': 4, 'estate': 4, 'close': 1, 'text': 1, 'input': 1, 'mobile': 3, 'top': 3, 'republican': 4, 'tax': 13, 'bill': 6, 'clears': 1, 'senate': 3, 'holdouts': 1, 'support': 1, 'sweeping': 1, 'overhaul': 1, 'decades': 1, 'jim': 1, 'tankersley': 1, 'thomas': 1, 'kaplan': 1, 'alan': 2, 'rappeport': 1, '542': 1, 'am': 8, 'et': 7, 'plan': 3, 'affects': 1, 'families': 1, 'owners': 1, 'multinational': 1, 'corporations': 1, 'biggest': 2, 'benefits': 1, 'flowing': 1, 'highestearning': 1, 'americans': 1, 'lawmakers': 1, 'received': 1, 'nearly': 1, '500page': 1, 'containing': 1, 'significant': 1, 'changes': 1, 'hours': 4, 'planned': 2, 'vote': 2, 'prompting': 1, 'outcry': 3, 'democrats': 1, 'voted': 1, 'hasty': 2, 'handscribbled': 2, 'sets': 2, 'gains': 1, 'economists': 1, 'heres': 3, 'deciphering': 1, 'gop': 2, 'ohio': 1, 'met': 3, 'ambivalence': 1, 'majority': 1, 'leader': 1, 'mitch': 1, 'mcconnell': 1, 'walked': 1, 'chamber': 1, 'conference': 1, 'fellow': 1, 'republicans': 3, 'friday': 1, 'credit': 2, 'tj': 1, 'kirkpatrick': 1, 'analysis': 3, 'deficit': 2, 'priority': 1, 'takes': 1, 'seat': 1, 'cuts': 2, 'binyamin': 1, 'appelbaum': 1, 'party': 1, 'criticized': 1, 'growth': 2, 'president': 7, 'barack': 1, 'obama': 1, 'cut': 3, 'send': 1, 'heights': 1, 'win': 1, 'political': 3, 'lift': 1, 'carl': 1, 'hulse': 1, 'sheryl': 2, 'gay': 4, 'stolberg': 2, '151': 1, 'muchneeded': 1, 'victory': 1, 'remains': 2, 'seen': 1, 'raises': 1, 'ditch': 1, 'flynn': 9, 'pleads': 2, 'guilty': 6, 'lying': 1, 'fbi': 1, 'nyt': 3, 'extrump': 1, 'aide': 1, 'cooperating': 1, 'russia': 5, 'inquiry': 1, 'michael': 4, 'shear': 1, 'adam': 1, 'goldman': 1, 'plea': 5, 'trumps': 5, 'former': 5, 'national': 2, 'adviser': 2, 'brings': 1, 'investigation': 2, 'russian': 3, 'interference': 1, '20 ...
#
#
# {'stack': 19, 'overflow': 14, 'developers': 4, 'learn': 6, 'share': 3, 'build': 3, 'careers': 2, 'questions': 9, 'developer': 3, 'jobs': 3, 'tags': 2, 'users': 1, 'current': 1, 'community': 2, 'help': 4, 'chat': 2, 'meta': 3, 'communities': 2, 'sign': 2, 'log': 2, 'customize': 1, 'list': 4, 'exchange': 4, 'company': 3, 'blog': 3, 'tour': 1, 'start': 3, 'quick': 1, 'overview': 1, 'site': 4, 'center': 1, 'detailed': 1, 'answers': 89, 'discuss': 1, 'workings': 1, 'policies': 1, 'business': 3, 'hiring': 1, 'posting': 1, 'ads': 2, 'month': 2, '50': 2, 'million': 1, 'knowledge': 1, 'join': 2, 'worlds': 1, 'largest': 1, 'google': 1, 'facebook': 4, 'display': 1, 'name': 4, 'email': 1, 'address': 1, 'password': 2, 'registering': 1, 'agree': 1, 'privacy': 2, 'policy': 2, 'terms': 1, 'service': 3, 'solutions': 1, 'looking': 2, 'understand': 1, 'engage': 1, 'hire': 1, 'raquo': 1, 'top': 1, '357': 1, 'featured': 1, 'hot': 3, 'week': 1, '0': 146, 'votes': 81, '1': 57, 'answer': 12, '4': 16, 'views': 96, 'unable': 6, 'connect': 1, 'remote': 1, 'sqlserver': 5, 'database': 6, 'local': 1, 'management': 1, 'studio': 3, 'answered': 13, '32': 3, 'secs': 5, 'ago': 96, 'alvin': 1, 'lau': 1, '5': 17, 'represent': 1, 'nested': 1, 'data': 10, 'structures': 1, 'using': 7, 'perl': 1, '6': 16, 'classes': 1, 'perl6': 1, 'modified': 33, '35': 1, 'eugene': 1, 'barsky': 1, '1150': 1, '2': 32, 'inner': 1, 'class': 4, 'implement': 1, 'interface': 1, 'java': 5, '36': 2, 'samuel': 1, 'jacques': 1, 'scurville': 1, 'scipy': 2, 'cdist': 1, 'pass': 2, 'arguments': 2, 'metric': 1, '47': 2, 'andreas': 1, 'georgiou': 1, 'disposition': 1, 'select': 1, 'utficons': 1, 'html': 3, 'googlechrome': 3, 'utf8': 1, 'symbols': 1, '58': 1, 'peter': 1, 'rader': 1, '5389': 1, 'wp': 1, 'api': 4, 'authentication': 2, 'spa': 1, 'wordpress': 2, 'wordpressrestapi': 1, 'nonce': 1, 'min': 7, 'philip': 1, 'feldmann': 1, '1096': 1, '3': 18, 'create': 4, 'factorygirl39s': 1, 'factory': 1, 'model': 1, 'ruby': 2, 'nikolay': 1, 'radionov': 1, '8': 10, 'cant': 1, 'install': 1, 'configuration': 2, 'profile': 1, 'encryption': 1, 'ios': 4, 'salmano2': 1, 'am': 3, 'getting': 3, 'dimensions': 1, 'misaligned': 1, 'value': 3, 'error': 5, 'scoring': 3, 'linear': 1, 'regression': 1, 'python': 15, 'linearregression': 1, 'robert': 1, 'dwyer': 1, '12': 13, 'php': 6, 'calculate': 1, 'daily': 1, 'weekly': 1, 'monthly': 1, 'basis': 1, 'based': 2, 'fixed': 1, 'prices': 1, 'datediff': 1, 'price': 1, 'mickmackusa': 1, '112k': 1, 'client': 2, 'custom': 3, 'properties': 3, 'authorization': 1, 'endpoint': 1, 'modelviewcontroller': 1, 'identityserver4': 1, 'arun': 1, 'pc': 1, 'power': 1, 'batch': 1, 'size': 1, 'increases': 1, 'beyond': 1, '18': 7, 'gpu': 1, 'machine': 1, 'tensorflow': 3, 'deeplearning': 1, 'trainingdata': 1, 'mxnet': 1, 'basile': 1, 'starynkevitch': 1, '152k': 1, 'edit': 1, 'input': 1, 'date': 1, 'time': 1, 'inside': 2, 'tablebut': 1, 'iam': 1, 'typing': 1, '1st': 1, 'suddenly': 1, 'triggered': 1, 'javascript': 9, 'mins': 80, 'anish': 1, 'kumar': 3, '26': 2, 'python3': 1, 'ldquotypeerror': 1, 'converted': 1, 'string': 2, 'formattingrdquo': 1, 'flask': 1, 'sqlalchemy': 1, 'flasksqlalchemy': 1, 'shilovk': 2, '4103': 2, 'embedding': 2, 'jython': 2, 'scala': 2, 'program': 1, 'bwbecker': 1, '397': 1, '7': 8, 'solve': 1, 'comadroidtoolsbuildgradle310alpha04': 1, 'android': 11, 'gradle': 1, 'prem': 2, '2676': 2, 'pandas': 2, 'merge': 2, 'can39t': 1, 'column': 1, 'tomasz': 2, 'dylewski': 1, 'tessdata': 1, 'tesseract': 1, 'git': 1, 'pytesser': 1, 'wolff': 1, '21': 3, 'delete': 2, 'derby': 2, 'system': 1, 'directory': 2, 'embedded': 1, 'apache': 3, 'embeddeddatabase': 1, 'adrian': 1, 'elder': 1, '552': 1, '9': 7, 'parse': 1, 'containing': 1, 'dictionary': 1, 'django': 2, 'presentation': 1, 'buddies': 1, 'vote': 15, 'redirect': 1, 'specific': 5, 'controller': 2, 'url': 2, 'starts': 1, 'xyz': 1, 'laravel': 4, 'htaccess': 1, 'sharath': 1, '451': 1, 'operation': 1, 'allowed': 1, 'active': 2, 'reactive': 1, 'context' ...
#
# ['raquo']
#
# ['raquo']
#
# ['0']
#
#
#
# [ KEYWORD : news ]
# --------------------------------------
#
# URL : http://www.times.com
# 키워드 news 가 포함된 단어 항목입니다
#
# [word] news : [similarity] 30
# [word] newsletter : [similarity] 2
# [word] newsletters : [similarity] 1
# --------------------------------------
# URL : http://www.apple.com/
# 키워드 news 가 존재하지 않습니다
#
# --------------------------------------
# URL : https://github.com
# 키워드 news 가 존재하지 않습니다
#
# --------------------------------------
# => ['http://www.times.com']
#
#
#
# [ KEYWORD : apple ]
# --------------------------------------
#
# URL : http://www.times.com
# 키워드 apple 가 포함된 단어 항목입니다
#
# [word] apple : [similarity] 21
# --------------------------------------
# URL : http://www.apple.com/
# 키워드 apple 가 포함된 단어 항목입니다
#
# [word] apple : [similarity] 40
# [word] applecom : [similarity] 1
# [word] 1800myapple : [similarity] 1
# --------------------------------------
# URL : https://github.com
# 키워드 apple 가 존재하지 않습니다
#
# --------------------------------------
# => ['http://www.apple.com/']

# %% [markdown]
# > - 먼저 새로운 클래스 WebWordsFrequency을 정의하고 생성자에서는 URL을 담는 리스트(urlList)와 {URL, {단어, 단어의 출현 빈도}}를 가지는 사전 객체(words)를 초기화해주고, for~in 구문을 돌면서 생성자의 인자에 나온 여러개의 url을 각각 addUrl(url) 함수를 호출해줍니다. <br><br>
# > - addUrl() 함수는 getWords() 함수를 호출하고 인자로 들어온 url의 값을 urlList에 append 합니다. <br><br>
# > - removeUrl() 함수는 인자로 들어온 url이 현재까지 들어온 url을 저장하는 리스트(urlList)에 존재하면 단어으 출현빈도를 저장하는 사전(word[url])을 del 식별자로 삭제하고 urlList에서 url 값을 remove 함수를 통해 삭제해줍니다.<br><br>
# > - listUrls() 함수에서는 현재 urlList에 존재하는 url 값을 출력해줍니다.<br><br>
# > - getWords() 함수는 Assignment 3의 방법으로 url을 가지고 와 해당 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어들을 추출하여 각 단어들에 대해 출현빈도를 사전형태로 저장하는 함수입니다. <br><br>
# > - getWordsFrequency() 함수는 해당 url의 웹페이지들을 종합적으로 분석하여 단어 출현 빈도 사전을 반환하는 함수로, 만약 등록된 url이 없다면 공백 사전을 반환합니다. 먼저 url을 등록하는 urlList의 갯수가 0이라면 공백 사전을 반환하고, 종합적으로 단어와 단어 출현비도를 키로 가지는 사전(totalWords)를 초기화합니다. for~in을 돌면서 words 사전에 저장된 키(url)와 벨류(word)를 읽어오고 사전 객체 words 사전의 키 중 totalWords에 저장되지 않은 것이 있으면 해당 키 값의 벨류 값을 totalWords에 저장하고, 이미 words 사전의 키가 totalWords에 저장되어있으면 현재 값에 words의 벨류 값을 더해줍니다. 마지막으로 totalWords 사전을 반환합니다.<br><br>
# > - getMaxFreqencyWords() 메소드를 구현하여 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현 빈도 사전에서 가장 많이 출현한 단어 리스트를 반환합니다. 만약 url을 등록하는 urlList의 갯수가 0이라면 None 객체를 반환하고 totalWords 값에 getWordsFrequency() 함수를 호출하여 종합적으로 분석된 사전객체를 넣어줍니다. 그리고 최다 출현 빈도수가 동일한 경우, 해당 단어를 모두 출력해주기 위해 단어를 저장할 리스트(tmp)를 초기화하고 최다출현 빈도수를 저장할 변수(maxv)를 0으로 초기화합니다. for~in 구문을 돌면서 totalWords에 저장된 키와 벨류값을 가져오면서 만약 저장된 최대값보다 현재 벨류값(출현빈도 값)이 더 크다면 최대값을 저장하는 변수(maxv)에 현재 벨류값을 저장해줍니다. 그리고 totalWords을 다시 돌면서 저장된 최대값이랑 동일한 출현빈도를 가진 단어가 나오면 리스트(tmp)에 저장합니다. 이 리스트는 원소 갯수가 하나 이상일 수 있습니다.(최다 출현 빈도를 가지는 단어가 여러개일 수 있기 때문에)<br><br>
# > - searchUrlByWord() 메소드는 유사도가 높은 웹사이트를 출력하는 메소드로 제가 Assignment 4에서 정의한 유사도 법칙에 따라 구현해주었습니다. 먼저 현재 url의 words의 키 값을 저장하는 temp와 유사도를 저장하는 사전 객체(similarity)을 초기화해줍니다. 그리고 url의 갯수만큼 for~in 구문을 돌면서 temp에 words[현재 url]의 키 값들을 리스트로 저장하고 만약 temp에 함수의 인자로 들어온 검색할 단어 keyword가 존재하면 기본 유사도를 10으로 줍니다. 그리고 temp의 길이만큼 반복문을 돌면서 입력받은 키워드기 단어의 일부일 경우, 해당 단어의 출현빈도를 similarity[현재 url]에 더해주고, 만약 단어이 일부가 아니라 키워드가 단어와 완전히 독같을 경우에는 출현빈도에 보너스 점수 20을 더한 것을 similarity[현재 url]에 더해줍니다. 만약 temp에 함수의 인자로 들어온 검색할 단어 keyword가 존재하지 않으면 키워드가 존재하지 않는다는 메시지를 출력해줍니다. 마지막으로 유사도가 가장 높은 웹사이트를 출력하기 위해 유사도의 최대값을 저장하는 maxv을 0으로 초기화해주고 유사도의 최대값이 동일한 웹사이트가 여러개 존재할 수 있으므로 이를 저장해줄 리스트(l)을 초기화합니다. for~in 구문을 similarity의 아이템 갯수만큼 돌면서 만약 similarity의 벨류값이 현재 저장된 최대값보다 크다면 maxv값을 similarity의 벨류값으로 저장해줍니다. 이 작업이 모두 끝나면 similarity의 아이템 갯수만큼 돌면서 similarity의 벨류값이 현재 저장된 유사도의 최대값과 같으면 리스트(l)에 추가해줍니다. 최종적으로 리스트(l)을 반환합니다.

# %% [markdown]
# ### 8번 문제

# %% [markdown]
# 위 7번 문제에서 정의한 WebWordsFrequency 클래스를 상속하여 OrderedWebWordsFrequency 클래스를 정의하고 슈퍼클래스에 정의된 getWordsFrequency() 메소드를 오버라이드 하여 단어 출현 빈도를 내림 차순으로 정렬하여 리스트로 출력하시오.
# - 리스트 내의 각 원소는 단어와 빈도를 쌍으로 지니는 튜플이다.
# - getWordFrequence() 메소드에 reverse 라는 인자를 만들고 true 또는 false를 인자로 받을 수 있도록 한다.
#     - reverse 인자의 디폴트 값은 false 이며, 기본적으로 내림차순으로 정렬한다.
#     - reverse 인자에 true를 넣으면 오름차순으로 정렬한다.
#     > ```>>> w4 = OrderedWebWordsFrequency('http://www.times.com', 'https://www.amazon.com', 'https://github.com')```
#
#     > ```>>> w4.getWordsFrequency()
# [('site', 12), ('science', 11), ('hello', 8), ('world', 2), ('program', 1), ('python', 1)]```
#
#     > ```>>> w4.getWordsFrequency(reverse=true)
# [('program', 1), ('python', 1), ('world', 2), ('hello', 8), ('science', 11), ('site', 12)]```

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def __init__(self, *l):
        WebWordsFrequency.__init__(self, *l)
    
    def getWordsFrequency(self, reverse = False):
        totalWords = WebWordsFrequency.getWordsFrequency(self)
        
        # 기본적으로 내림차순 정렬 후 반환
        li = []
        temp = list(totalWords.values())
        temp.sort(reverse = not reverse)
        for value in temp:
            for key in totalWords.keys():
                if value == totalWords[key]:
                    li.append((key, totalWords[key]))
                    del totalWords[key]
                    break
        return li

# %%
# amazon에서 HTML 소스를 읽는 것을 막아놔서 다른 예제로 작성하였습니다.
w4 = OrderedWebWordsFrequency('http://www.times.com', 'http://edition.cnn.com', 'https://github.com')
print(w4.getWordsFrequency())
print()
print()
print(w4.getWordsFrequency(reverse=True))
# Out:
# [('raquo', 34), ('github', 26), ('times', 16), ('news', 15), ('business', 15), ('video', 14), ('tax', 13), ('york', 12), ('opinion', 12), ('trump', 11), ('review', 11), ('cnn', 11), ('international', 11), ('world', 10), ('site', 10), ('security', 10), ('code', 10), ('health', 9), ('flynn', 9), ('comments', 9), ('edition', 9), ('sign', 9), ('learn', 8), ('search', 8), ('navigation', 8), ('arts', 8), ('am', 8), ('help', 8), ('house', 8), ('home', 8), ('2017', 7), ('travel', 7), ('magazine', 7), ('et', 7), ('president', 7), ('developers', 7), ('politics', 6), ('style', 6), ('food', 6), ('bill', 6), ('guilty', 6), ('flynns', 6), ('white', 6), ('education', 6), ('community', 6), ('terms', 6), ('features', 6), ('subscribe', 5), ('todays', 5), ('tech', 5), ('russia', 5), ('plea', 5), ('trumps', 5), ('former', 5), ('policy', 5), ('people', 5), ('china', 5), ('10', 5), ('books', 5), ('guide', 5), ('own', 5), ('—', 5), ('theater', 5), ('subscriptions', 5), ('story', 5), ('play', 5), ('set', 5), ('privacy', 5), ('tv', 5), ('project', 5), ('worldwide', 5), ('software', 5), ('build', 5), ('teams', 5), ('maintainer', 5), ('sections', 4), ('español', 4), ('2', 4), ('science', 4), ('sports', 4), ('real', 4), ('estate', 4), ('republican', 4), ('hours', 4), ('gay', 4), ('michael', 4), ('officials', 4), ('daily', 4), ('living', 4), ('editorial', 4), ('future', 4), ('crossword', 4), ('apps', 4), ('fashion', 4), ('city', 4), ('tools', 4), ('account', 4), ('arabic', 4), ('preference', 4), ('confirm', 4), ('africa', 4), ('luxury', 4), ('culture', 4), ('platform', 4), ('breaking', 3), ('nytimescom', 3), ('skip', 3), ('mobile', 3), ('top', 3), ('senate', 3), ('plan', 3), ('outcry', 3), ('heres', 3), ('met', 3), ('republicans', 3), ('analysis', 3), ('cut', 3), ('send', 3), ('political', 3), ('nyt', 3), ('russian', 3), ('create', 3), ('campaign', 3), ('damage', 3), ('roy', 3), ('moore', 3), ('gloria', 3), ('allred', 3), ('sexual', 3), ('harassment', 3), ('firing', 3), ('lauer', 3), ('nbc', 3), ('tillerson', 3), ('donors', 3), ('status', 3), ('death', 3), ('generation', 3), ('special', 3), ('notable', 3), ('black', 3), ('recipes', 3), ('ice', 3), ('familiar', 3), ('british', 3), ('supermoon', 3), ('information', 3), ('worlds', 3), ('football', 3), ('youre', 3), ('plans', 3), ('million', 3), ('family', 3), ('struggling', 3), ('videos', 3), ('inside', 3), ('dont', 3), ('tell', 3), ('college', 3), ('oped', 3), ('sending', 3), ('media', 3), ('matter', 3), ('sailing', 3), ('dies', 3), ('architecture', 3), ('feature', 3), ('sale', 3), ('jayz', 3), ('tennis', 3), ('design', 3), ('nyc', 3), ('events', 3), ('manage', 3), ('email', 3), ('service', 3), ('weather', 3), ('regions', 3), ('sport', 3), ('vr', 3), ('development', 3), ('marketplace', 3), ('projects', 3), ('alongside', 3), ('management', 3), ('using', 3), ('integrations', 3), ('hosting', 3), ('signed', 3), ('multimedia', 2), ('internet', 2), ('upgrade', 2), ('content', 2), ('english', 2), ('december', 2), ('paper', 2), ('quick', 2), ('ny', 2), ('support', 2), ('alan', 2), ('biggest', 2), ('planned', 2), ('vote', 2), ('hasty', 2), ('handscribbled', 2), ('sets', 2), ('gop', 2), ('credit', 2), ('deficit', 2), ('cuts', 2), ('growth', 2), ('sheryl', 2), ('stolberg', 2), ('remains', 2), ('pleads', 2), ('national', 2), ('adviser', 2), ('brings', 2), ('investigation', 2), ('2016', 2), ('election', 2), ('inner', 2), ('circle', 2), ('power', 2), ('documents', 2), ('charges', 2), ('lawyer', 2), ('chairman', 2), ('ties', 2), ('memo', 2), ('baker', 2), ('administration', 2), ('rival', 2), ('afar', 2), ('jess', 2), ('six', 2), ('control', 2), ('john', 2), ('matt', 2), ('reports', 2), ('fire', 2), ('recognize', 2), ('jerusalem', 2), ('embassy', 2), ('tel', 2), ('aviv', 2), ('california', 2), ('protections', 2), ('360', 2), ('wont', 2), ('sean', 2), ('hannity', 2), ('facing', 2), ('audio', 2), ('public', 2), ('hear', 2), ('weeks', 2), ('jon', 2), ('comeback', 2), ('300', 2), ('gifts', 2), ('holiday', 2), ('gift', 2), ('ma ...
#
# ---------------------------------------------------------------------------------------------------------------------------------------
#
# [('supports', 1), ('explorer', 1), ('9', 1), ('earlier', 1), ('please', 1), ('browser', 1), ('log', 1), ('0', 1), ('settings', 1), ('中文', 1), ('chinese', 1), ('saturday', 1), ('close', 1), ('text', 1), ('input', 1), ('clears', 1), ('holdouts', 1), ('sweeping', 1), ('overhaul', 1), ('decades', 1), ('jim', 1), ('tankersley', 1), ('thomas', 1), ('kaplan', 1), ('rappeport', 1), ('542', 1), ('affects', 1), ('families', 1), ('owners', 1), ('multinational', 1), ('corporations', 1), ('benefits', 1), ('flowing', 1), ('highestearning', 1), ('americans', 1), ('lawmakers', 1), ('received', 1), ('nearly', 1), ('500page', 1), ('containing', 1), ('significant', 1), ('changes', 1), ('prompting', 1), ('democrats', 1), ('voted', 1), ('gains', 1), ('economists', 1), ('deciphering', 1), ('ohio', 1), ('ambivalence', 1), ('majority', 1), ('leader', 1), ('mitch', 1), ('mcconnell', 1), ('walked', 1), ('chamber', 1), ('conference', 1), ('fellow', 1), ('friday', 1), ('tj', 1), ('kirkpatrick', 1), ('priority', 1), ('takes', 1), ('seat', 1), ('binyamin', 1), ('appelbaum', 1), ('party', 1), ('criticized', 1), ('barack', 1), ('obama', 1), ('heights', 1), ('win', 1), ('lift', 1), ('carl', 1), ('hulse', 1), ('151', 1), ('muchneeded', 1), ('victory', 1), ('seen', 1), ('raises', 1), ('ditch', 1), ('lying', 1), ('fbi', 1), ('extrump', 1), ('aide', 1), ('cooperating', 1), ('inquiry', 1), ('shear', 1), ('adam', 1), ('goldman', 1), ('interference', 1), ('discussions', 1), ('sergey', 1), ('kislyak', 1), ('ambassador', 1), ('effort', 1), ('aides', 1), ('foreign', 1), ('court', 1), ('left', 1), ('react', 1), ('attorney', 1), ('eldest', 1), ('son', 1), ('soninlaw', 1), ('longtime', 1), ('advisers', 1), ('binding', 1), ('jasmine', 1), ('lee', 1), ('karen', 1), ('yourish', 1), ('eight', 1), ('corresponded', 1), ('transition', 1), ('cooperation', 1), ('casts', 1), ('pall', 1), ('peter', 1), ('maggie', 1), ('haberman', 1), ('legal', 1), ('danger', 1), ('uncertain', 1), ('wrought', 1), ('grievous', 1), ('332', 1), ('led', 1), ('niraj', 1), ('chokshi', 1), ('robin', 1), ('stein', 1), ('ainara', 1), ('tiefenthäler', 1), ('shane', 1), ('oneill', 1), ('bidgood', 1), ('blinder', 1), ('fights', 1), ('claims', 1), ('misconduct', 1), ('candidate', 1), ('alabama', 1), ('vilified', 1), ('representing', 1), ('accuser', 1), ('taxpayer', 1), ('funds', 1), ('covered', 1), ('settlement', 1), ('yamiche', 1), ('alcindor', 1), ('1222', 1), ('rep', 1), ('blake', 1), ('farenthold', 1), ('texas', 1), ('settled', 1), ('suit', 1), ('84000', 1), ('settlements', 1), ('funded', 1), ('taxpayers', 1), ('2013', 1), ('koblin', 1), ('competitors', 1), ('raised', 1), ('questions', 1), ('division', 1), ('reassure', 1), ('staff', 1), ('handling', 1), ('scandal', 1), ('denies', 1), ('gardiner', 1), ('harris', 1), ('denied', 1), ('rex', 1), ('secretary', 1), ('referred', 1), ('rumors', 1), ('“laughable”', 1), ('mark', 1), ('landler', 1), ('julie', 1), ('hirschfeld', 1), ('davis', 1), ('trying', 1), ('appease', 1), ('evangelical', 1), ('supporters', 1), ('powerful', 1), ('jewish', 1), ('avoid', 1), ('derailing', 1), ('administrations', 1), ('peace', 1), ('efforts', 1), ('resolute', 1), ('sanctuary', 1), ('heated', 1), ('jennifer', 1), ('medina', 1), ('acquittal', 1), ('mexican', 1), ('woman', 1), ('renewed', 1), ('calls', 1), ('tougher', 1), ('border', 1), ('measures', 1), ('held', 1), ('firm', 1), ('undocumented', 1), ('immigrants', 1), ('deported', 1), ('repeatedly', 1), ('sentenced', 1), ('35', 1), ('attacks', 1), ('115', 1), ('wall', 1), ('robb', 1), ('kendrick', 1), ('confidential', 1), ('tip', 1), ('offers', 1), ('touch', 1), ('provide', 1), ('materials', 1), ('journalists', 1), ('11', 1), ('weekend', 1), ('reads', 1), ('kaly', 1), ('soto', 1), ('pieces', 1), ('miss', 1), ('japan', 1), ('lonely', 1), ('listen', 1), ('episode', 1), ('tells', 1), ('federal', 1), ('prosecutors', 1), ('senior', 1), ('follow', 1), ('apple', 1), ('podcasts', 1), ('radio', 1), ('stitcher', 1), ('smarter', 1), ('playlist', 1),  ...

# %% [markdown]
# > - 먼저 OrderedWebWordsFrequency 클래스는 WebWordsFrequency 클래스를 상속받습니다. 그리고 ```__init___()``` 함수를 정의하고 이 함수 내에서는 부모 클래스인 WebWordsFrequency 클래스의  ```__init___()``` 함수를 호출합니다. <br><br>
#
# > - getWordsFrequency 함수에서는 인자로 reverse 값이 들어가는데, 디폴트값을 False으로 설정해놓습니다. 그리고 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현빈도를 저장하는 사전(totalWords)에 부모 클래스의 getWordsFrequency() 함수를 호출해줍니다. 기본적으로 출현빈도의 내림차순(즉, 사전의 벨류값을 기준으로 내림차순)으로 정렬하므로 totalWords의 벨류값들을 저장하는 리스트(temp)을 선언하고, 이를 sort 함수를 통해 정렬해줍니다. 여기서 reverse 값은 현재 getWordsFrequency에서 들어온 인자값 reverse에 not을 붙이면 됩니다. 이렇게 하는 이유는 현재 getWordsFrequency 함수의 reverse는 디폴트값으로 False를 설정해놓는데, 이는 내림차순을 기본으로 한다는 것입니다. 하지만 sort 함수에서는 reverse의 값을 True로 지정해주면 내림차순으로 되기 때문입니다. 반복문을 돌면서 totalWords의 벨류값을 저장하는 리스트(temp)에서 하나의 벨류값(value)을 뽑고, totalWords의 키값들을 뽑아 반복문을 돌면서 하나의 키값(key)에 해당하는 벨류값이 value와 동일하면 사전의 벨류값을 기준으로 정렬된 리스트를 저장하는 li에 해당 키와 벨류값을 저장시켜줍니다. 그리고 li에 저장된 totalWords의 벨류값을 지워주고 break 합니다. (이렇게 해주는 이유는 다음 정렬시 동일한 벨류값의 접근을 막기 위함) 마지막으로 정렬된 li을 반환합니다.

# %% [markdown]
# ### 9번 문제

# %% [markdown]
# 다음과 같은 코딩이 가능하도록 OrderedWebWordsFrequency 안에 반복자와 관련된 메소드를 추가하시오.
# > ```>>> for i in w4:```<br>
# > ```>>>       print(i)```<br>
# > ('site, 12)<br>
# > ('science', 11)<br>
# > ('hello', 8)<br>
# > ('world', 2)<br>
# > ('program', 1)<br>
# > ('python', 1)<br>

# %%
class OrderedWebWordsFrequency(WebWordsFrequency):
    def __init__(self, *l):
        WebWordsFrequency.__init__(self, *l)
    
    def getWordsFrequency(self, reverse = False):
        totalWords = WebWordsFrequency.getWordsFrequency(self)
        
        # 기본적으로 내림차순 정렬 후 반환
        li = []
        temp = list(totalWords.values())
        temp.sort(reverse = not reverse)
        for value in temp:
            for key in totalWords.keys():
                if value == totalWords[key]:
                    li.append((key, totalWords[key]))
                    del totalWords[key]
                    break
        return li
    
    def __iter__(self):
        self.i = -1
        self.tmpFrequency = self.getWordsFrequency()
        return self
    
    def __next__(self):
        self.i += 1
        if len(self.tmpFrequency) <= self.i:
            raise StopIteration
            
        return self.tmpFrequency[self.i]

# %%
w4 = OrderedWebWordsFrequency('http://www.times.com', 'http://edition.cnn.com', 'https://github.com')
for i in w4:
    print(i)
# Out:
# ('raquo', 34)
# ('github', 26)
# ('business', 15)
# ('times', 14)
# ('news', 14)
# ('video', 14)
# ('tax', 13)
# ('review', 13)
# ('opinion', 12)
# ('york', 11)
# ('trump', 11)
# ('cnn', 11)
# ('international', 11)
# ('world', 10)
# ('site', 10)
# ('help', 10)
# ('security', 10)
# ('comments', 10)
# ('code', 10)
# ('health', 9)
# ('flynn', 9)
# ('home', 9)
# ('edition', 9)
# ('sign', 9)
# ('learn', 8)
# ('search', 8)
# ('navigation', 8)
# ('arts', 8)
# ('magazine', 8)
# ('house', 8)
# ('et', 7)
# ('—', 7)
# ('city', 7)
# ('developers', 7)
# ('politics', 6)
# ('food', 6)
# ('bill', 6)
# ('am', 6)
# ('president', 6)
# ('guilty', 6)
# ('flynns', 6)
# ('people', 6)
# ('white', 6)
# ('own', 6)
# ('teams', 6)
# ('story', 6)
# ('education', 6)
# ('community', 6)
# ('terms', 6)
# ('features', 6)
# ('subscribe', 5)
# ('2017', 5)
# ('todays', 5)
# ('tech', 5)
# ('style', 5)
# ('travel', 5)
# ('russia', 5)
# ('michael', 5)
# ('plea', 5)
# ('trumps', 5)
# ('former', 5)
# ('policy', 5)
# ('10', 5)
# ('subscriptions', 5)
# ('play', 5)
# ('set', 5)
# ('privacy', 5)
# ('tv', 5)
# ('project', 5)
# ('worldwide', 5)
# ('software', 5)
# ('build', 5)
# ('maintainer', 5)
# ('breaking', 4)
# ('sections', 4)
# ('español', 4)
# ('2', 4)
# ('science', 4)
# ('sports', 4)
# ('real', 4)
# ('estate', 4)
# ('top', 4)
# ('republican', 4)
# ('hours', 4)
# ('gay', 4)
# ('officials', 4)
# ('sexual', 4)
# ('living', 4)
# ('guide', 4)
# ('worlds', 4)
# ('editorial', 4)
# ('future', 4)
# ('crossword', 4)
# ('china', 4)
# ('theater', 4)
# ('fashion', 4)
# ('books', 4)
# ('tools', 4)
# ('account', 4)
# ('arabic', 4)
# ('preference', 4)
# ('confirm', 4)
# ('africa', 4)
# ('luxury', 4)
# ('culture', 4)
# ('platform', 4)
# ('nytimescom', 3)
# ('upgrade', 3)
# ('skip', 3)
# ('mobile', 3)
# ('senate', 3)
# ('plan', 3)
# ('outcry', 3)
# ('met', 3)
# ('republicans', 3)
# ('analysis', 3)
# ('growth', 3)
# ('cut', 3)
# ('send', 3)
# ('political', 3)
# ('nyt', 3)
# ('russian', 3)
# ('2016', 3)
# ('create', 3)
# ('charges', 3)
# ('campaign', 3)
# ('damage', 3)
# ('tillerson', 3)
# ('firing', 3)
# ('roy', 3)
# ('moore', 3)
# ('gloria', 3)
# ('allred', 3)
# ('harassment', 3)
# ('highprofile', 3)
# ('donors', 3)
# ('special', 3)
# ('hear', 3)
# ('notable', 3)
# ('holiday', 3)
# ('building', 3)
# ('move', 3)
# ('forward', 3)
# ('information', 3)
# ('football', 3)
# ('death', 3)
# ('love', 3)
# ('store', 3)
# ('artist', 3)
# ('stars', 3)
# ('potatoes', 3)
# ('plans', 3)
# ('million', 3)
# ('family', 3)
# ('struggling', 3)
# ('videos', 3)
# ('inside', 3)
# ('dont', 3)
# ('tell', 3)
# ('europe', 3)
# ('college', 3)
# ('oped', 3)
# ('sending', 3)
# ('media', 3)
# ('matter', 3)
# ('sailing', 3)
# ('dies', 3)
# ('architecture', 3)
# ('apps', 3)
# ('feature', 3)
# ('sale', 3)
# ('jayz', 3)
# ('tennis', 3)
# ('design', 3)
# ('nyc', 3)
# ('events', 3)
# ('manage', 3)
# ('email', 3)
# ('service', 3)
# ('weather', 3)
# ('regions', 3)
# ('sport', 3)
# ('vr', 3)
# ('development', 3)
# ('marketplace', 3)
# ('projects', 3)
# ('alongside', 3)
# ('management', 3)
# ('using', 3)
# ('integrations', 3)
# ('hosting', 3)
# ('signed', 3)
# ('multimedia', 2)
# ('content', 2)
# ('english', 2)
# ('december', 2)
# ('paper', 2)
# ('quick', 2)
# ('ny', 2)
# ('support', 2)
# ('alan', 2)
# ('biggest', 2)
# ('changes', 2)
# ('planned', 2)
# ('vote', 2)
# ('hasty', 2)
# ('handscribbled', 2)
# ('sets', 2)
# ('heres', 2)
# ('gop', 2)
# ('deficit', 2)
# ('cuts', 2)
# ('sheryl', 2)
# ('stolberg', 2)
# ('remains', 2)
# ('pleads', 2)
# ('inquiry', 2)
# ('national', 2)
# ('adviser', 2)
# ('brings', 2)
# ('investigation', 2)
# ('election', 2)
# ('inner', 2)
# ('circle', 2)
# ('power', 2)
# ('documents', 2)
# ('attorney', 2)
# ('lawyer', 2)
# ('ties', 2)
# ('memo', 2)
# ('cooperation', 2)
# ('baker', 2)
# ('pm', 2)
# ('administration', 2)
# ('reports', 2)
# ('fire', 2)
# ('rival', 2)
# ('afar', 2)
# ('jess', 2)
# ('misconduct', 2)
# ('six', 2)
# ('mea', 2)
# ('culpa', 2)
# ('sorta', 2)
# ('journalists', 2)
# ('issued', 2)
# ('lauer', 2)
# ('nbc', 2)
# ('control', 2)
# ('chinas', 2)
# ('boom', 2)
# ('jerusalem', 2)
# ('embassy', 2)
# ('tel', 2)
# ('aviv', 2)
# ('audio', 2)
# ('daily', 2)
# ('tells', 2)
# ('public', 2)
# ('weeks', 2)
# ('jon', 2)
# ('comeback', 2)
# ('300', 2)
# ('gifts', 2)
# ('gift', 2)
# ('matters', 2)
# ('system', 2)
# ('scandals', 2)
# ('government', 2)
# ('american', 2)
# ('attack', 2)
# ('soccer', 2)
# ('transplants', 2)
# ('training', 2)
# ('water', 2)
# ('police', 2)
# ('shooting', 2)
# ('black', 2)
# ('life', 2)
# ('dealbook', 2)
# ('newsletter', 2)
# ('major', 2)
# ('shape', 2)
# ('australia', 2)
# ('battery', 2)
# ('ruled', 2)
# ('data', 2)
# ('windows', 2)
# ('sort', 2)
# ('disaster', 2)
# ('look', 2)
# ('worst', 2)
# ('kitchen', 2)
# ('meat', 2)
# ('historic', 2)
# ('heist', 2)
# ('generations', 2)
# ('cost', 2)
# ('kushner', 2)
# ('don', 2)
# ('jr', 2)
# ('norman', 2)
# ('presidents', 2)
# ('flipped', 2)
# ('whos', 2)
# ('writing', 2)
# ('prime', 2)
# ('minister', 2)
# ('assignment', 2)
# ('camping', 2)
# ('walmart', 2)
# ('photographers', 2)
# ('camp', 2)
# ('insider', 2)
# ('todayrsquos', 2)
# ('puzzle', 2)
# ('watching', 2)
# ('neediest', 2)
# ('loading', 2)
# ('explore', 2)
# ('jenna', 2)
# ('lyonss', 2)
# ('space', 2)
# ('book', 2)
# ('buy', 2)
# ('sunday', 2)
# ('fail', 2)
# ('fatigue', 2)
# ('music', 2)
# ('opera', 2)
# ('welcome', 2)
# ('generation', 2)
# ('money', 2)
# ('cant', 2)
# ('contributors', 2)
# ('facebook', 2)
# ('social', 2)
# ('movies', 2)
# ('acting', 2)
# ('studios', 2)
# ('draw', 2)
# ('eyes', 2)
# ('hundreds', 2)
# ('obituaries', 2)
# ('influential', 2)
# ('television', 2)
# ('jeanclaude', 2)
# ('van', 2)
# ('damme', 2)
# ('36', 2)
# ('choosing', 2)
# ('youre', 2)
# ('live', 2)
# ('automobiles', 2)
# ('detroit', 2)
# ('america', 2)
# ('calculator', 2)
# ('permits', 2)
# ('index', 2)
# ('services', 2)
# ('newsletters', 2)
# ('copy', 2)
# ('company', 2)
# ('contact', 2)
# ('advertise', 2)
# ('entertainment', 2)
# ('americas', 2)
# ('asia', 2)
# ('middle', 2)
# ('east', 2)
# ('45', 2)
# ('congress', 2)
# ('nine', 2)
# ('trumpmerica', 2)
# ('markets', 2)
# ('screen', 2)
# ('binge', 2)
# ('gadgets', 2)
# ('startups', 2)
# ('equestrian', 2)
# ('golf', 2)
# ('judo', 2)
# ('horse', 2)
# ('racing', 2)
# ('motorsport', 2)
# ('skiing', 2)
# ('olympics', 2)
# ('destinations', 2)
# ('drink', 2)
# ('stay', 2)
# ('autos', 2)
# ('diet', 2)
# ('fitness', 2)
# ('parenting', 2)
# ('vital', 2)
# ('signs', 2)
# ('freedom', 2)
# ('impact', 2)
# ('degrees', 2)
# ('heroes', 2)
# ('hln', 2)
# ('schedule', 2)
# ('cnnvr', 2)
# ('watch', 2)
# ('archives', 2)
# ('profiles', 2)
# ('leadership', 2)
# ('pressroom', 2)
# ('partner', 2)
# ('sites', 2)
# ('ireport', 2)
# ('source', 2)
# ('host', 2)
# ('millions', 2)
# ('username', 2)
# ('password', 2)
# ('clicking', 2)
# ('agree', 2)
# ('occasionally', 2)
# ('related', 2)
# ('emails', 2)
# ('team', 2)
# ('happen', 2)
# ('share', 2)
# ('browse', 2)
# ('discover', 2)
# ('authentication', 2)
# ('status', 2)
# ('maintain', 2)
# ('access', 2)
# ('securely', 2)
# ('cloud', 2)
# ('process', 2)
# ('theres', 2)
# ('largest', 2)
# ('customer', 2)
# ('personal', 2)
# ('businesses', 2)
# ('tab', 2)
# ('window', 2)
# ('reload', 2)
# ('refresh', 2)
# ('session', 2)
# ('supports', 1)
# ('internet', 1)
# ('explorer', 1)
# ('9', 1)
# ('earlier', 1)
# ('please', 1)
# ('browser', 1)
# ('log', 1)
# ('0', 1)
# ('settings', 1)
# ('中文', 1)
# ('chinese', 1)
# ('saturday', 1)
# ('close', 1)
# ('text', 1)
# ('input', 1)
# ('clears', 1)
# ('holdouts', 1)
# ('sweeping', 1)
# ('overhaul', 1)
# ('decades', 1)
# ('jim', 1)
# ('tankersley', 1)
# ('thomas', 1)
# ('kaplan', 1)
# ('rappeport', 1)
# ('434', 1)
# ('affects', 1)
# ('families', 1)
# ('owners', 1)
# ('multinational', 1)
# ('corporations', 1)
# ('benefits', 1)
# ('flowing', 1)
# ('highestearning', 1)
# ('americans', 1)
# ('lawmakers', 1)
# ('received', 1)
# ('nearly', 1)
# ('500page', 1)
# ('containing', 1)
# ('significant', 1)
# ('prompting', 1)
# ('democrats', 1)
# ('voted', 1)
# ('gains', 1)
# ('economists', 1)
# ('deciphering', 1)
# ('ohio', 1)
# ('ambivalence', 1)
# ('majority', 1)
# ('leader', 1)
# ('mitch', 1)
# ('mcconnell', 1)
# ('walked', 1)
# ('chamber', 1)
# ('conference', 1)
# ('fellow', 1)
# ('friday', 1)
# ('credit', 1)
# ('tj', 1)
# ('kirkpatrick', 1)
# ('priority', 1)
# ('takes', 1)
# ('seat', 1)
# ('binyamin', 1)
# ('appelbaum', 1)
# ('party', 1)
# ('criticized', 1)
# ('barack', 1)
# ('obama', 1)
# ('heights', 1)
# ('win', 1)
# ('lift', 1)
# ('carl', 1)
# ('hulse', 1)
# ('151', 1)
# ('muchneeded', 1)
# ('victory', 1)
# ('seen', 1)
# ('raises', 1)
# ('ditch', 1)
# ('lying', 1)
# ('fbi', 1)
# ('extrump', 1)
# ('aide', 1)
# ('cooperating', 1)
# ('shear', 1)
# ('adam', 1)
# ('goldman', 1)
# ('interference', 1)
# ('discussions', 1)
# ('sergey', 1)
# ('kislyak', 1)
# ('ambassador', 1)
# ('effort', 1)
# ('aides', 1)
# ('foreign', 1)
# ('court', 1)
# ('left', 1)
# ('react', 1)
# ('eldest', 1)
# ('son', 1)
# ('soninlaw', 1)
# ('longtime', 1)
# ('advisers', 1)
# ('chairman', 1)
# ('binding', 1)
# ('jasmine', 1)
# ('lee', 1)
# ('karen', 1)
# ('yourish', 1)
# ('eight', 1)
# ('corresponded', 1)
# ('transition', 1)
# ('casts', 1)
# ('pall', 1)
# ('peter', 1)
# ('maggie', 1)
# ('haberman', 1)
# ('1120', 1)
# ('legal', 1)
# ('danger', 1)
# ('uncertain', 1)
# ('wrought', 1)
# ('grievous', 1)
# ('332', 1)
# ('led', 1)
# ('niraj', 1)
# ('chokshi', 1)
# ('robin', 1)
# ('stein', 1)
# ('ainara', 1)
# ('tiefenthäler', 1)
# ('shane', 1)
# ('oneill', 1)
# ('denies', 1)
# ('gardiner', 1)
# ('harris', 1)
# ('denied', 1)
# ('rex', 1)
# ('secretary', 1)
# ('referred', 1)
# ('rumors', 1)
# ('“laughable”', 1)
# ('bidgood', 1)
# ('blinder', 1)
# ('fights', 1)
# ('claims', 1)
# ('candidate', 1)
# ('alabama', 1)
# ('vilified', 1)
# ('representing', 1)
# ('accuser', 1)
# ('taxpayer', 1)
# ('funds', 1)
# ('covered', 1)
# ('settlement', 1)
# ('yamiche', 1)
# ('alcindor', 1)
# ('1222', 1)
# ('rep', 1)
# ('blake', 1)
# ('farenthold', 1)
# ('texas', 1)
# ('settled', 1)
# ('suit', 1)
# ('84000', 1)
# ('settlements', 1)
# ('funded', 1)
# ('taxpayers', 1)
# ('2013', 1)
# ('analyze', 1)
# ('apologies', 1)
# ('nonapologies', 1)
# ('accused', 1)
# ('overlook', 1)
# ('schuman', 1)
# ('highways', 1)
# ('trains', 1)
# ('farming', 1)
# ('countrys', 1)
# ('poorer', 1)
# ('cities', 1)
# ('rural', 1)
# ('laggards', 1)
# ('amid', 1)
# ('torrid', 1)
# ('recognizes', 1)
# ('mark', 1)
# ('landler', 1)
# ('julie', 1)
# ('hirschfeld', 1)
# ('davis', 1)
# ('trying', 1)
# ('appease', 1)
# ('evangelical', 1)
# ('supporters', 1)
# ('powerful', 1)
# ('jewish', 1)
# ('avoid', 1)
# ('derailing', 1)
# ('administrations', 1)
# ('peace', 1)
# ('efforts', 1)
# ('confidential', 1)
# ('tip', 1)
# ('offers', 1)
# ('touch', 1)
# ('provide', 1)
# ('materials', 1)
# ('listen', 1)
# ('episode', 1)
# ('federal', 1)
# ('prosecutors', 1)
# ('senior', 1)
# ('follow', 1)
# ('apple', 1)
# ('podcasts', 1)
# ('radio', 1)
# ('stitcher', 1)
# ('smarter', 1)
# ('playlist', 1)
# ('songs', 1)
# ('pareles', 1)
# ('caramanica', 1)
# ('giovanni', 1)
# ('russonello', 1)
# ('releases', 1)
# ('beyoncé', 1)
# ('joining', 1)
# ('ed', 1)
# ('sheeran', 1)
# ('craig', 1)
# ('davids', 1)
# ('24', 1)
# ('healthy', 1)
# ('soups', 1)
# ('stews', 1)
# ('cooking', 1)
# ('75', 1)
# ('editors', 1)
# ('15', 1)
# ('categories', 1)
# ('journalism', 1)
# ('essential', 1)
# ('mexico', 1)
# ('block', 1)
# ('anticorruption', 1)
# ('drive', 1)
# ('azam', 1)
# ('ahmed', 1)
# ('nations', 1)
# ('graft', 1)
# ('inaugurated', 1)
# ('enrique', 1)
# ('peña', 1)
# ('nieto', 1)
# ('routinely', 1)
# ('thwarted', 1)
# ('singlefamily', 1)
# ('conor', 1)
# ('dougherty', 1)
# ('housing', 1)
# ('densely', 1)
# ('address', 1)
# ('widespread', 1)
# ('economic', 1)
# ('challenge', 1)
# ('fight', 1)
# ('lot', 1)
# ('berkeley', 1)
# ('calif', 1)
# ('tough', 1)
# ('motives', 1)
# ('egypt', 1)
# ('terrorist', 1)
# ('religion', 1)
# ('revenge', 1)
# ('nour', 1)
# ('youssef', 1)
# ('1041', 1)
# ('311', 1)
# ('killed', 1)
# ('packed', 1)
# ('mosque', 1)
# ('sinai', 1)
# ('town', 1)
# ('residents', 1)
# ('probably', 1)
# ('payback', 1)
# ('egyptian', 1)
# ('forces', 1)
# ('sex', 1)
# ('plagiarism', 1)
# ('spyware', 1)
# ('copyright', 1)
# ('complaint', 1)
# ('alexandra', 1)
# ('alter', 1)
# ('dueling', 1)
# ('lawsuits', 1)
# ('novelist', 1)
# ('emma', 1)
# ('cline', 1)
# ('exboyfriend', 1)
# ('involve', 1)
# ('lawyers', 1)
# ('kidney', 1)
# ('yielded', 1)
# ('soccers', 1)
# ('secret', 1)
# ('weapon', 1)
# ('rory', 1)
# ('smith', 1)
# ('terry', 1)
# ('nelson', 1)
# ('inventor', 1)
# ('buoyancy', 1)
# ('suits', 1)
# ('clubs', 1)
# ('found', 1)
# ('helped', 1)
# ('prosecutor', 1)
# ('indicted', 1)
# ('killing', 1)
# ('jesse', 1)
# ('mckinley', 1)
# ('yorks', 1)
# ('brought', 1)
# ('stemming', 1)
# ('motorist', 1)
# ('troy', 1)
# ('rensselaer', 1)
# ('county', 1)
# ('da', 1)
# ('joel', 1)
# ('abelove', 1)
# ('andy', 1)
# ('webster', 1)
# ('plenty', 1)
# ('sampling', 1)
# ('cultural', 1)
# ('highlights', 1)
# ('weekend', 1)
# ('week', 1)
# ('ahead', 1)
# ('honduras', 1)
# ('declares', 1)
# ('curfew', 1)
# ('protests', 1)
# ('count', 1)
# ('continue', 1)
# ('exnsa', 1)
# ('employee', 1)
# ('taking', 1)
# ('classified', 1)
# ('failed', 1)
# ('fronts', 1)
# ('charlottesville', 1)
# ('rally', 1)
# ('exmarine', 1)
# ('prison', 1)
# ('okinawa', 1)
# ('rape', 1)
# ('murder', 1)
# ('columnist', 1)
# ('andrew', 1)
# ('ross', 1)
# ('sorkin', 1)
# ('colleagues', 1)
# ('sense', 1)
# ('headlines', 1)
# ('brokers', 1)
# ('allnew', 1)
# ('powers', 1)
# ('courtesy', 1)
# ('elon', 1)
# ('musk', 1)
# ('south', 1)
# ('blackout', 1)
# ('tesla', 1)
# ('founder', 1)
# ('solution', 1)
# ('size', 1)
# ('field', 1)
# ('30', 1)
# ('mans', 1)
# ('fall', 1)
# ('australian', 1)
# ('cliff', 1)
# ('hate', 1)
# ('crime', 1)
# ('1988', 1)
# ('scott', 1)
# ('johnson', 1)
# ('mathematician', 1)
# ('initially', 1)
# ('suicide', 1)
# ('emerged', 1)
# ('gangs', 1)
# ('pushing', 1)
# ('deaths', 1)
# ('tracking', 1)
# ('elusive', 1)
# ('whale', 1)
# ('shark', 1)
# ('study', 1)
# ('includes', 1)
# ('photos', 1)
# ('identifying', 1)
# ('sea', 1)
# ('creatures', 1)
# ('especially', 1)
# ('hang', 1)
# ('believe', 1)
# ('rightish', 1)
# ('bedazzled', 1)
# ('vitrines', 1)
# ('season', 1)
# ('james', 1)
# ('franco', 1)
# ('directs', 1)
# ('fictionalized', 1)
# ('“the', 1)
# ('room”', 1)
# ('fans', 1)
# ('call', 1)
# ('movie', 1)
# ('rack', 1)
# ('lamb', 1)
# ('rubbed', 1)
# ('mustard', 1)
# ('rosemary', 1)
# ('roasted', 1)
# ('crushed', 1)
# ('comfortfood', 1)
# ('favorite', 1)
# ('elevated', 1)
# ('elegance', 1)
# ('pick', 1)
# ('childrens', 1)
# ('pockets', 1)
# ('bear', 1)
# ('terrible', 1)
# ('awaits', 1)
# ('richard', 1)
# ('painter', 1)
# ('eisen', 1)
# ('deal', 1)
# ('door', 1)
# ('takeaways', 1)
# ('collins', 1)
# ('deck', 1)
# ('halls', 1)
# ('folly', 1)
# ('stephens', 1)
# ('speed', 1)
# ('clinton', 1)
# ('124', 1)
# ('ehud', 1)
# ('barak', 1)
# ('save', 1)
# ('israel', 1)
# ('benjamin', 1)
# ('netanyahus', 1)
# ('ruling', 1)
# ('coalition', 1)
# ('irrational', 1)
# ('bordering', 1)
# ('messianic', 1)
# ('vandalizing', 1)
# ('wild', 1)
# ('heritage', 1)
# ('bruce', 1)
# ('babbitt', 1)
# ('repeal', 1)
# ('protections', 1)
# ('acres', 1)
# ('land', 1)
# ('cohen', 1)
# ('farthest', 1)
# ('burmese', 1)
# ('journey', 1)
# ('user', 1)
# ('clearing', 1)
# ('air', 1)
# ('climate', 1)
# ('reporter', 1)
# ('returns', 1)
# ('scene', 1)
# ('wordplay', 1)
# ('fleeing', 1)
# ('antisemitism', 1)
# ('finding', 1)
# ('hope', 1)
# ('“i', 1)
# ('american”', 1)
# ('anatoliy', 1)
# ('krongauz', 1)
# ('united', 1)
# ('surviving', 1)
# ('holocaust', 1)
# ('facing', 1)
# ('continued', 1)
# ('discrimination', 1)
# ('106th', 1)
# ('fund', 1)
# ('provided', 1)
# ('direct', 1)
# ('assistance', 1)
# ('beyond', 1)
# ('donate', 1)
# ('advertisers', 1)
# ('player', 1)
# ('previous', 1)
# ('fix', 1)
# ('universities', 1)
# ('giant', 1)
# ('tortoise', 1)
# ('streaming', 1)
# ('elites', 1)
# ('taste', 1)
# ('medicine', 1)
# ('saudi', 1)
# ('arabias', 1)
# ('royals', 1)
# ('rich', 1)
# ('immune', 1)
# ('failures', 1)
# ('kingdoms', 1)
# ('brutal', 1)
# ('mind', 1)
# ('trauma', 1)
# ('fallout', 1)
# ('youd', 1)
# ('loved', 1)
# ('doctors', 1)
# ('women', 1)
# ('babies', 1)
# ('revisiting', 1)
# ('chronic', 1)
# ('phantom', 1)
# ('dreams', 1)
# ('hes', 1)
# ('britain', 1)
# ('endorsement', 1)
# ('fringe', 1)
# ('farright', 1)
# ('undermines', 1)
# ('country', 1)
# ('relationship', 1)
# ('sean', 1)
# ('hannity', 1)
# ('migrants', 1)
# ('stopped', 1)
# ('sold', 1)
# ('slaves', 1)
# ('forgiveness', 1)
# ('pope', 1)
# ('francis', 1)
# ('rohingya', 1)
# ('muslims', 1)
# ('bangladesh', 1)
# ('japan', 1)
# ('lonely', 1)
# ('day', 1)
# ('matt', 1)
# ('executives', 1)
# ('wealth', 1)
# ('office', 1)
# ('stocks', 1)
# ('rose', 1)
# ('investors', 1)
# ('worried', 1)
# ('earnings', 1)
# ('majors', 1)
# ('kinda', 1)
# ('technology', 1)
# ('shift', 1)
# ('41', 1)
# ('lithuania', 1)
# ('feed', 1)
# ('drone', 1)
# ('maker', 1)
# ('dji', 1)
# ('snapchat', 1)
# ('remakes', 1)
# ('splitting', 1)
# ('tied', 1)
# ('opioid', 1)
# ('sales', 1)
# ('invite', 1)
# ('question', 1)
# ('museums', 1)
# ('vet', 1)
# ('upright', 1)
# ('citizens', 1)
# ('brigade', 1)
# ('closes', 1)
# ('filthy', 1)
# ('fanfare', 1)
# ('john', 1)
# ('adams', 1)
# ('mines', 1)
# ('gold', 1)
# ('rush', 1)
# ('history', 1)
# ('looms', 1)
# ('verge', 1)
# ('success', 1)
# ('recognize', 1)
# ('capital', 1)
# ('modern', 1)
# ('toddler', 1)
# ('belong', 1)
# ('qs', 1)
# ('friend', 1)
# ('diagnoses', 1)
# ('altogether', 1)
# ('wonderful', 1)
# ('wonder', 1)
# ('wheel', 1)
# ('woody', 1)
# ('allens', 1)
# ('coney', 1)
# ('island', 1)
# ('memory', 1)
# ('palace', 1)
# ('moviemaking', 1)
# ('paid', 1)
# ('parental', 1)
# ('leave', 1)
# ('except', 1)
# ('fewer', 1)
# ('contracting', 1)
# ('hiv', 1)
# ('yankees', 1)
# ('choose', 1)
# ('aaron', 1)
# ('boone', 1)
# ('manager', 1)
# ('applause', 1)
# ('cheering', 1)
# ('cup', 1)
# ('groupbygroup', 1)
# ('silly', 1)
# ('seas', 1)
# ('pirates', 1)
# ('penzance', 1)
# ('visionary', 1)
# ('nourished', 1)
# ('backstage', 1)
# ('broadway', 1)
# ('scallop', 1)
# ('spaceage', 1)
# ('2017s', 1)
# ('supermoon', 1)
# ('moons', 1)
# ('super', 1)
# ('trilobites', 1)
# ('fossilized', 1)
# ('pterosaur', 1)
# ('eggs', 1)
# ('uncovered', 1)
# ('adventurer', 1)
# ('89', 1)
# ('crossed', 1)
# ('atlantic', 1)
# ('reed', 1)
# ('raft', 1)
# ('leon', 1)
# ('cooper', 1)
# ('carried', 1)
# ('battle', 1)
# ('tarawa', 1)
# ('98', 1)
# ('vincent', 1)
# ('scully', 1)
# ('97', 1)
# ('historian', 1)
# ('plays', 1)
# ('kicks', 1)
# ('word', 1)
# ('claire', 1)
# ('foy', 1)
# ('ready', 1)
# ('quit', 1)
# ('playing', 1)
# ('queen', 1)
# ('obamacare', 1)
# ('mandate', 1)
# ('floodgates', 1)
# ('skimpy', 1)
# ('causes', 1)
# ('bells', 1)
# ('palsy', 1)
# ('weekly', 1)
# ('quiz', 1)
# ('running', 1)
# ('mysterious', 1)
# ('bacteria', 1)
# ('getaway', 1)
# ('sos', 1)
# ('rise', 1)
# ('las', 1)
# ('vegas', 1)
# ('renewing', 1)
# ('vows', 1)
# ('embracing', 1)
# ('shanghai', 1)
# ('enthusiast', 1)
# ('praise', 1)
# ('career', 1)
# ('romance', 1)
# ('100', 1)
# ('colleges', 1)
# ('applicant', 1)
# ('getting', 1)
# ('dream', 1)
# ('myths', 1)
# ('pasteles', 1)
# ('puerto', 1)
# ('rican', 1)
# ('tradition', 1)
# ('savor', 1)
# ('sicilys', 1)
# ('emerald', 1)
# ('green', 1)
# ('gem', 1)
# ('bronte', 1)
# ('pistachio', 1)
# ('answer', 1)
# ('eat', 1)
# ('ice', 1)
# ('cream', 1)
# ('cake', 1)
# ('ethicist', 1)
# ('raging', 1)
# ('bigot', 1)
# ('ferry', 1)
# ('changing', 1)
# ('brooklynqueens', 1)
# ('waterfront', 1)
# ('ticket', 1)
# ('38', 1)
# ('penthouse', 1)
# ('west', 1)
# ('chelsea', 1)
# ('novembers', 1)
# ('renters', 1)
# ('jersey', 1)
# ('upshot', 1)
# ('grumpy', 1)
# ('unhappy', 1)
# ('50', 1)
# ('bills', 1)
# ('automatic', 1)
# ('spending', 1)
# ('respond', 1)
# ('editor', 1)
# ('reading', 1)
# ('pleasantville', 1)
# ('dec', 1)
# ('16', 1)
# ('event', 1)
# ('table', 1)
# ('exciting', 1)
# ('indian', 1)
# ('automakers', 1)
# ('plant', 1)
# ('wheels', 1)
# ('near', 1)
# ('driving', 1)
# ('hands', 1)
# ('discusses', 1)
# ('rap', 1)
# ('marriage', 1)
# ('studio', 1)
# ('painted', 1)
# ('construction', 1)
# ('kolomatsky', 1)
# ('types', 1)
# ('recent', 1)
# ('queens', 1)
# ('brooklyn', 1)
# ('homes', 1)
# ('rent', 1)
# ('mortgage', 1)
# ('emailed', 1)
# ('viewed', 1)
# ('trending', 1)
# ('recommended', 1)
# ('page', 1)
# ('corrections', 1)
# ('columnists', 1)
# ('editorials', 1)
# ('letters', 1)
# ('art', 1)
# ('dance', 1)
# ('jobs', 1)
# ('weddings', 1)
# ('celebrations', 1)
# ('listings', 1)
# ('reader', 1)
# ('center', 1)
# ('classifieds', 1)
# ('photography', 1)
# ('journeys', 1)
# ('nytco', 1)
# ('delivery', 1)
# ('digital', 1)
# ('alerts', 1)
# ('rate', 1)
# ('applications', 1)
# ('replica', 1)
# ('ad', 1)
# ('choices', 1)
# ('map', 1)
# ('feedback', 1)
# ('view', 1)
# ('version', 1)
# ('espantildeol', 1)
# ('twitter', 1)
# ('instagram', 1)
# ('copy2017cablenewsnetwork', 1)
# ('turnerbroadcastingsysteminc', 1)
# ('allrightsreserved', 1)
# ('cnnsanstradecopy2016cablenewsnetwork', 1)
# ('adchoices', 1)
# ('msa', 1)
# ('statement', 1)
# ('transcripts', 1)
# ('license', 1)
# ('footage', 1)
# ('newsource', 1)
# ('world39s', 1)
# ('leading', 1)
# ('pricing', 1)
# ('dashboard', 1)
# ('built', 1)
# ('inspired', 1)
# ('otherdevelopers', 1)
# ('letter', 1)
# ('numeral', 1)
# ('seven', 1)
# ('characters', 1)
# ('ideas', 1)
# ('write', 1)
# ('collaboration', 1)
# ('makes', 1)
# ('perfect', 1)
# ('conversations', 1)
# ('reviews', 1)
# ('pull', 1)
# ('requests', 1)
# ('weight', 1)
# ('improve', 1)
# ('chaos', 1)
# ('deep', 1)
# ('breath', 1)
# ('happens', 1)
# ('issues', 1)
# ('mention', 1)
# ('teammate', 1)
# ('involved', 1)
# ('favorites—then', 1)
# ('start', 1)
# ('minutes', 1)
# ('boxes', 1)
# ('check', 1)
# ('worry', 1)
# ('administrative', 1)
# ('flexible', 1)
# ('options', 1)
# ('meet', 1)
# ('requirements', 1)
# ('prevent', 1)
# ('protected', 1)
# ('branches', 1)
# ('commits', 1)
# ('required', 1)
# ('checks', 1)
# ('protect', 1)
# ('standard', 1)
# ('controlled', 1)
# ('encourage', 1)
# ('limiting', 1)
# ('granular', 1)
# ('permissions', 1)
# ('samlsso', 1)
# ('ldap', 1)
# ('1clrcodehosting', 1)
# ('hosted', 1)
# ('reliably', 1)
# ('githubcom', 1)
# ('deploy', 1)
# ('enterprise', 1)
# ('servers', 1)
# ('private', 1)
# ('amazon', 1)
# ('web', 1)
# ('azure', 1)
# ('google', 1)
# ('compare', 1)
# ('customize', 1)
# ('intuitive', 1)
# ('api', 1)
# ('integrate', 1)
# ('favorites', 1)
# ('happier', 1)
# ('efficient', 1)
# ('sometimes', 1)
# ('tool', 1)
# ('job', 1)
# ('try', 1)
# ('theirprojects', 1)
# ('ariya', 1)
# ('hidayat', 1)
# ('phantomjs', 1)
# ('russell', 1)
# ('keithmagee', 1)
# ('pybee', 1)
# ('mailchimp', 1)
# ('marketing', 1)
# ('kris', 1)
# ('nova', 1)
# ('kuberneteskops', 1)
# ('evan', 1)
# ('vue', 1)
# ('mapbox', 1)
# ('frazelle', 1)
# ('kubernetes', 1)
# ('previously', 1)
# ('docker', 1)
# ('commit', 1)
# ('rover', 1)
# ('mars', 1)
# ('72m', 1)
# ('repositories', 1)
# ('githubs', 1)
# ('users', 1)
# ('technologies', 1)
# ('sourcecommunity', 1)
# ('26m', 1)
# ('experimenting', 1)
# ('programming', 1)
# ('languages', 1)
# ('lifes', 1)
# ('117k', 1)
# ('sizes', 1)
# ('started', 1)
# ('free', 1)
# ('mdash', 1)
# ('join', 1)
# ('amazing', 1)
# ('documentation', 1)
# ('atom', 1)
# ('electron', 1)
# ('desktop', 1)
# ('customers', 1)
# ('partners', 1)
# ('sponsorships', 1)
# ('blog', 1)
# ('careers', 1)
# ('press', 1)
# ('shop', 1)
# ('resources', 1)
# ('forum', 1)
# ('perform', 1)
# ('action', 1)
# ('time', 1)

# %% [markdown]
# > - OrderedWebWordsFrequency은 부모 클래스인 WebWordsFrequency을 상속받고 ```__init__()``` 함수와 getWordsFrequency 함수는 위의 문제와 동일합니다. <br><br>
# > - 그리고 반복자와 관련된 메소드 ``` __iter__()```와 ```__next__()```을 정의해줍니다. 먼저 ```__iter__()```에서는 객체 변수 i을 -1으로 초기화해주고, 객체변수 tmpFrequency에 각 URL의 웹페이지들을 종합적으로 분석한 단어 출현빈도 사전을 반환하는 getWordsFrequency 함수를 호출해주고, 현재 객체를 반환해줍니다. <br><br>
# > - ```__next__()```에서는 객체변수 i를 하나 증가시키고 만약 tmpFrequency의 길이가 self.i보다 작거나 같으면 raise StopIteration을 통해 예외를 발생시켜줍니다. 그렇지 않다면 현재 위치의 tmpFrequency 값을 반환해줍니다.

# %% [markdown]
# ---
# 소감 : 중간고사에 비해 배우는 파이썬의 개념이 어려워지면서 수업을 들어도 정확하게 제가 아는 것인지 확신이 없었습니다. 하지만 이번 과제를 통해 그동안 어렵다고 생각이 들었던 함수와 클래스, 반복자의 내용을 복습할 수 있어서 좋았습니다. 이번이 마지막 과제라고 하니 한학기를 시작한지 얼마안된 것 같은데 벌써 한학기가 지났다는 것이 신기하기도 하고 섭섭하기도 하네요.. 한연희 교수님의 수업을 들어본 게 이번이 처음인데 정말 많은 것을 배우고 갑니다. 교수님의 수업을 들으면 연구하고 싶어지는 생각이 들고 더 알고 싶다는 생각이 드네요. 수업에서 해주셨던 많은 조언들, 잊지 않고 꼭 기억하겠습니다!!!!!! 수업을 들으면서 방학 때 python을 이용한 데이터 처리나 딥러닝에 대해서 공부하겠다는 결심도 했습니다. 정말 감사드리고 항상 몸 조심하세요!
